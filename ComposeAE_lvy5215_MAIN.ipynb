# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Specify the name of the new folder
new_folder_name = '/content/data/mitstates'

# Create a new folder
os.makedirs(new_folder_name, exist_ok=True)

# Check if the folder is created
if os.path.exists(new_folder_name):
    print(f"Folder '{new_folder_name}' created successfully.")
else:
    print(f"Failed to create folder '{new_folder_name}'.")
# Out:
# Folder '/content/data/mitstates' created successfully.

# %%
import os

# Specify the name of the new folder
new_folder_name = '/content/logs/mitstates'

# Create a new folder
os.makedirs(new_folder_name, exist_ok=True)

# Check if the folder is created
if os.path.exists(new_folder_name):
    print(f"Folder '{new_folder_name}' created successfully.")
else:
    print(f"Failed to create folder '{new_folder_name}'.")
# Out:
# Folder '/content/logs/mitstates' created successfully.

# %%
# !export KAGGLE_USERNAME="JeonghanYYoon"
# !export KAGGLE_KEY="08769ab1e7df43fb56d211642d2cf185"
# !curl -L -o /content/mitstates.zip -H "Authorization: Bearer $KAGGLE_KEY" https://www.kaggle.com/api/v1/datasets/download/binhhuunguyen/mitstates
# !unzip /content/mitstates.zip -d /content/mitstates
# !echo "Dataset downloaded and extracted successfully!"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0Uluru-2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0Uluru-4.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0V05415019.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0daylightsculpture1.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0joshua-tree-canyon-scene1a.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0kalahari_desert.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0parks-12-sm.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0saguaros-cactus-21220748.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0usaz33441.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant desert/ex0verdant-desert.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/41Z2BiQBLIJL.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/dirt20road20along20the20canal.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0087.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex013.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex014.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0313586487_8a81291b70.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0512809-130729-grass.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0526907-life-inside-north-korea.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0DSCN4686.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0GBCexterior.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0Group-photo-of-GUP-clients-with-Chris-Shaibu-and-Beth.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_0603.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_0609.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_0629.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_1497.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_3342.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_3348.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_3350.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_3351.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0IMG_3430.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0P6102502.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0U9817P18DT20140527152257.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0d00ad10f4ed2fea1e75ee3d5a0a10352.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0guan-yin-xia-china-verdant-farmlands-14808844.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0w4_aud803_md79.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0welcom1.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0welcom2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant farm/ex0xin_06311072416468753187859.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/Neuron_Space2C_LightWave_3D.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/Podere20Gli20Ulivi2003.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/Podere20Gli20Ulivi2005.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/Podere20Gli20Ulivi2007.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/Podere20Gli20Ulivi2008.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex00217131306a.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex00887665b3dd8bfac20881a070688ece3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex015-gall-i-ra-19202.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex02629866033_6e45629516_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex02925008988_70c87b6a32_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0339771972_f249ec90ab_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex04279743670_458e1dc3b8_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex04934072689_cda10642f9_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex057593070.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex05808005763_bb36ac80fa_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex061b1b4098bef1b3c2b560b134e4f0f30.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0IMG_00000183.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0New-Zealand.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0P1010174_2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0SAM_2098_1.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0Vatnsdalur030820081.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0Verdant_Field.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0cb_mc_chinampa_bh_final2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0fountains-abbey.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0martin-rak.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0rice-plant-verdant-field-thailand-33551934.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0road-field-and-sky.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0verdant-field2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/ex0verdant_field_hokkaido_japan_AFD-HAN-11483.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant field/vista2Bwallpapers2Bhd2Bwidescreen-2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ForestviewBueRiverCostaRica19Mar2013.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex00351A176.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex01012175_10151723596304884_138467937_n.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex02607153856_919652136c_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex032f28e94892a41a3d50e98986f85e6fe.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex03471774-77910-green-and-verdant-forest-at-the-repovesi-national-park.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex04791246-403431-big-waterfall-in-a-green-lush-and-verdant-forest-in-singapore.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex04b03d4a3f4797507dad0f54d0d361be3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0628x471.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex063af9630788526dff7a938acf43bebab.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex06794216203_22b93fde43_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex07-Hatu-Trek-A-Pleasant-Walk-through-Verdant-Forest.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex07094649945_3ae07409b3_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex080f56028f94025da033cefc28e3a9fac.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0Coba-Mexico-Coba-Ruins-5.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0DSC03160.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0IMG_5351.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0SceneryMontDAmbre1FF_CM.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0VerdantForest-1024x626.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0Verdant_Forest_by_ZeekPunk.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0ba5fc01ba81e3b938aa6b41249936dd9.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0deadtrees2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0df39b49f509943558857a219843409f8.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0dscn8152.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0guytighth.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0p9110030.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0rushing-waters-verdant-forest-hukere-creek-nelson-lakes-national-park-new-zealand-31944357.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0serene_verdant_black_walnut_forest_grove_5x7_nature_art_photo_254869a9.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0stone-stairs-lush-verdant-forest-38297047.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0verdant-forest-3012822.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0verdant-forest-959860.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0verdant_forest_and_emerald_dragon_by_kocosplay-d78ylk0.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/ex0zoo_9105.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant forest/flat550x550075f.u2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/DoubleCanal.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/Mana-Projects20Uber20Verdant-master-plan.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex002f705da06ba78379f19924241cd0c7c.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex035279.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex0Hellebores-dark-flowers-seedling-Feb-28-2012.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex0Hike-Willow-001.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex0birches-in-the-fierce-cold-dawn.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex0drop-dead-gorgeous.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex0dsc_1483.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex0tahitiblog.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant ground/ex0vg-tomato-seedlings.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/Picture20126.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/SaoMiguel-departure.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/SaoMiguel-departure2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0001a382abe1a085484a0464e959aaf27.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0018_91.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex011225_Urania-Luxury-Villas-17.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex01e8b0ed19d5fb2d88d06fccb72740a4f.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex059d74bc0e318257e35e4f53502dbf975.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex06250122833_51914d7650_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex06ec3074bc04d7489a6ff7f37c4526159.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex07482721094_67aea0ba87_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0adaaran-hudhuranfushi-23252475-1398165355-ImageGalleryLightbox.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0adaaran-hudhuranfushi-23252505-1398165355-ImageGalleryLightbox.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0angsana-ihuru-23242702-1399892630-ImageGalleryLightbox.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0area4.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0area_512_id_370.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0dfc5a278997e873c0d0ddd85b7aa0309.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0dsc01732.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0e38e2b378216673b87a597adb31a43a4.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0fd30659ad069963cf7569495839c8707.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0fdcf37eb2744dbc7f04f04eded3d58c8.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0reststop1024.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant island/ex0reststop21024.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0087cb16fc11b7bb5000243c37c7de3c3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex010de74562bfd21cf93ee734b5effbe60.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex012465465383_ca907cf959_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0130097-dragons-small-dragon-hunting.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex020100706-10373824.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex020abaf3e0485ba3131010ac1d3d80a0a.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex03042.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex03465686706_5c8c0b9939_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex06918890610_a8e3e127b9_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex08dd1e0a901a789de_4306-w660-h437-b0-p0---.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0G4797_a.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0IMG_4392.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0IMG_4403.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0Perspective-bamboo-bridge-Nha-Trang-Vietnam-Thiery-Beyne-NOI-Pictures-3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0bbe15daed612cc2adc6b804d19badfc3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0c59fbd4587bd448ffed0d6d44daa05b2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0img_11591.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant jungle/ex0tropicalskyrim.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex01007L22-071.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0923076010_cc07587be5_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex09679518205_c17e6d6433_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0IMG_3610.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0The_Lake_Club_Lake_Las_Vegas_FogartyFOTO-0375.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0U9611P704DT20130711085205.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0ancient-stone-bridge-lake-8694259.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0argentina_andes_sediments_1168x755.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0jeepsafari.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0patagonia_lake_district-40.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0sunrise_over_a_verdant_lake_shore_in_the_canadian_shield_pinawa_manitoba_canada_1943267.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0tzoo.dp.media.12609.90940.resort-squaw-creek.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant lake/ex0verdant-plant-background-11620196.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/AFG_5984(800x530).jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/Beachfront20Deluxe.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/DonaJovitaResortLagunaDSC0946411-4-200811-41-01AM.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/MGA_Property_in20Garda_CDS_1019.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/Main20photo.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/Verdant_Mountain27s_Violent_Wind.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0100036891_6a96ba4e19_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex01289801889_16616c84d6_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex024924_374296488019_411019_n.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0539221-d5ab6230-62df-11e4-a822-f0e45dcacc2e.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0781-19-mass-villa-kothmale-sri-lanka.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0Casa-Narigua-Mexico-00-630x315.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0IMG_3132.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0IMG_3134.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0SanOrfrieSkyline.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0cycling-tour-in-armenia_44_lush-mountains-of-tavush-2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0dsc07965.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0hiking-in-the-hudson-river-valley-view-2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0kefj36713.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0lake_mathieson1_with_shadow.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant mountain/ex0tumblr_luqet00OUx1r2i7s0o2_1280.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/2006-0820-20DESOLATION20WILDERNESS-00120284829-L.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex003W5eZL6d90S4_70.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex010777905453_41602fa0e6_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex01850188_com_lakeandveg.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex02c857862117ba6468af55bd0510bb2bf.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0Cornus_florida_e800.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0EASTCDOMMINCANTREE.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0Highgate-Cemetery.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0IMG_3384_0.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0IMG_3417_0.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0IMG_3418_0.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0c700x420.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0carnation01.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0cc8580c57db50dfff511f9ee6d2a7188.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0day-five.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0euphorbias_3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0euphorbias_4.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0narciss01.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0rose02.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0tulip01.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0verdant-cacti-picture-was-taken-xiamen-botanical-garden-china-cactus-contains-lot-water-their-leaves-stems-30934273.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant plant/ex0woodlandpicture.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex008.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex009.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex014575812062_2ef3550456_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex0180a2ed196f420997564712a01a117ad.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex0558535_10150826877507767_533822766_9608487_413630032_n.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex05f38077f4c360ea6d4eafedbe8fe5e68.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex087_2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex091_4.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex0Clearing-Storm-in-Gorge.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex0MILLER-GALISTEO-PHOTOGRAPHS-7.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex0county-durham-river-view-130804340.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex0f62b7962c9e2a4f5c7ec10299be382e2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex0rowingteam-1.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant river/ex0teesta_river.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant road/ex020060521214809589_13.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant road/ex02435810414_c520090474_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant road/ex08440016231_e27591db81_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant road/ex0cf2d0404fa768521f4dfe650debdc363.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant road/ex0img_3250-2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant shore/ex0Manaus_BoatsOnAmazon_Jorge-Luis-Cardosode-Andrade_CC-BY.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant shore/ex0Oregon_NorthUmpquaRiverLakeoftheWoods_TracyFox_123rf1024.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant shore/ex0george_town_shore.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/LitchfiedNP-WalkerCreek-Rockpool7252802529.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/LitchfiedNP-WalkerCreek-Rockpool7252822529.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/LitchfiedNP-WalkerCreekRockPool6252852529.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/LitchfiledNP-MagneticTermiteMounds252822529.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/ex011847625575_73e8ef204c_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/ex02008_10_10_Spain_Cadiz_plaza_de_mina-2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/ex02008_10_10_Spain_Cadiz_plaza_de_san_francisco-9.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/ex0Houses_of-Parliament_London-1.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/ex0Luisiana.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/ex0banjaluk.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant town/ex0d676cc0c-b89f-49eb-a894-0921a00c2b7d_1_404-3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex010-verdant-central-road.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex020121008-nm-tex-0818.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex020121008-nm-tex-0854.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex020121008-nm-tex-0869.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0247.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0Red-Oleander-2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0fieldtree2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0home_slide3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0home_slide4.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0home_slide7.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-10.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-11.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-12.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-18.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-19.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-24.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-25.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-26.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-27.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-28.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-3.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-43.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-45.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-46.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-47.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-51.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-54.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-55.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-56.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-57.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-6.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-60.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-62.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-64.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-67.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-72.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-73.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-8.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-87.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0install-9.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0nov_2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant tree/ex0rhapis-ladypalm.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0050b74d2f9ffa1c4bd7e7ea13cf334a2.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex00f73f03c6885cefd57065ecdb32df22b.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex02330978170_5018c44e93_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex03601711997_d28d17cd94_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex03755905047_86a9d20347_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex041170378.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex05416187300_2f12c658d2_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex05927954743_44f571ab92_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex05d2924c2995dbc81505c49f1e12a873d.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex06191722425_020dcd543f_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex061e5291f126e420daffe6216848bb791.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex09078492679_3f73fa49b1_z.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex09200542814_7f07d5aeec.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex096b0c4fd90930476af3acbfaaa987442.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0Hood-River.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0P10401351.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0VerdantValley.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0aim_bn_2_1309454045.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0indi11489.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0ph2797949780080183838.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0verdant-valley-michele-burgess.jpg
#   inflating: /content/mitstates/release_dataset/images/verdant valley/ex0verdant-valley.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/P1180556252822529.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/P1180573(2).jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0030314_ate005.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0120929_0000.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0152163_pcl.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex05335492487_5a9da94e18_z.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex05336105452_b636fcdac5_z.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0AntoniaLealpostup-CXWorlds-LouisvilleKy.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0DSC00946.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0Dierks_7_4upMuleTeam.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0IMG_0828-01.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0IMG_0836-01.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0IMG_0840-01.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0IMG_0841-01.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0Samona4_045-1000x579.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0Spring.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0b3211144-njia-panda.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0b3211148-njia-panda-primary-school.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0b3211153-njia-panda-mud.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0blollop.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0cemetery-gg-cemetery-damage2-081114-web-jpg.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0cemetery-gg-cemetery-damage5-081114-web-jpg.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0forest-springs4.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0graded01.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0graded10.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0maccalube.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0p1140582.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous mud/ex0turbid-springs2.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/JohnKinsella-PortadaantologC3ADa.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/REPAIRelement18.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex007.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex015Semi_Automatic_Cream_Fill_500x500.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex016.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0197651194_640.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex020099221932591.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex02394793644_ff90cfde40_z.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex02394806758_9c54a064a2_z.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex025.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0437094.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0437101.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0437110.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0437138.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0August2014-040.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0Dabu-print-akola-titli-block-design.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0Grilled_meat_paste_flavor.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0IMG_7056.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0IMG_8604.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0Manual-Cream-font-b-paste-b-font-font-b-filler-b-font-5-50ml-stainless-steel.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0PAINT286.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0Shiokara.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0Shirako.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0Texapon_n70_SLES_Sodium_Lauryl_Ether_Sulfate.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0Tuna-eyeball.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0c2-650x487.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0expa-syl_retrac.paste_caps_20pk.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0fecivol-sh-500x500.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0main18.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0mastic-lining-500x500.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0nPtwMYW.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0p1020627web.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0p1020629web.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0pl1493458-90_high_purity_rhamnolipid_biofungicide_brown_viscous_paste.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0roots_strong_style_color_b82220_oil_strong_pump_lca.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0sea-salt.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/ex0soft-polyvinyl-acetate-500x500.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous paste/glycerinadded.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/CasaBelissima20006.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex020130111-236590-Urubamba-bistec-encebollado-edit.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex04349308206_84d10eb9b9_z.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex04349309578_20408cc4d2_z.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex04349311062_f8a33498f8_z.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex04628643062_591f057f2d_b.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex04628644614_fbff471347_b.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex069c803ed97c9ca0.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex07245482770_9a41a687a4_z.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0FFZ67XHH5IRW5DE.MEDIUM.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0IMG_0025.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0IMG_1230.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0IMG_2345.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0IMG_4691.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0SDC13065.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0bbpr3.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0bbpr6.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0bbpr7.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0frenchdressing.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0img_0037.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0kunitoraya-japanese-udon-restaurant-paris-france-onigiri-10.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0kunitoraya-japanese-udon-restaurant-paris-france-onigiri-9.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0pako-salad.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0rad-naah-at-janetira.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0tk_crabew.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0tk_crabwm.jpg
#   inflating: /content/mitstates/release_dataset/images/viscous sauce/ex0tom_jenkins_barbecue_anthony_cave.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered beach/ex00092556037272.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered beach/ex010468849863_47190b08ea_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered beach/ex01089939127_5b20181523_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered beach/ex05908145566_20061b4327_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered beach/ex0beach-weathered-wood.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered beach/ex0weathered_beach.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/9DSC01978.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/Flat20Weathered20Boulder20(Medium).jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0051001m.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex01.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex02.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex02313006_75d52627.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex03.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex03743880485_e5727cc136_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex04.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex04841608056_e1af0f6885_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex05580076616_0cf19c140a_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex06.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex06247671552_c0660a893e.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex06944992176_e7f61cca77_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex07503570572_5d2cb0faf1_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex07799542296_180cf071f4_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex08126393928_6dae05d5e1_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex09607940918_89555ca1d9_z.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex09fed5532377d61bb33abc31e410ecfb6.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0C0136562-Onion_skin_boulder-SPL.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0IMG_7086.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0WeatheredBoulder01.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0WeatheredBoulder02.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0WeatheredBoulder03.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0WeatheredBoulder04.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0b9d2ed9432a554e70e1c236a4ec49ff3.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0bon_rock4.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0crevice-spiny-lizard.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0f25e8af2872d03480e7e6929b328125b.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0img_0507.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0img_0509.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0img_5050.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered boulder/ex0weathered-boulder-invercargill.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/(KGrHqZoQFCsFzpUeUBQsFG5QWw_32-705x688-0-0.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex001868b161ed7e1f5894b4f6e69732468.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex010822397_1.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex011426-WB-1000.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex011426-wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex01581-R2-1000.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex01583-r2_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex016543-WB-1000.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex017025-WB-1000.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex017029.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0226259.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex02607528e5a4205cd17aa00488702a77e.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex027009-R2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex027030-R2-1000.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex028406-01-1000.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex04453-r2_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex08e5ab3f94acb698388e92b35e8abc1e8.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0A26117-R2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0Folding_Purse_Hook_Brass.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0PL20-WB.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0a9f69859d612fb460b2a9ad8c3ae080c.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0b26edd1655d4ec10b48aa5622bff0440.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0candle-lamp-190wb-weathered-brass-sleeve-lamp-base.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1050wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1146wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1151wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1152wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1197wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1556wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1557wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1567wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1575wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1834wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb1841wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0cb6027wb_l_2.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0contemporary-table-lamps.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0dl10-wb.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0e38a5c42f53efc91c466718d1a00442f.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0e4acdf89d3c054a032b66c6aa20a029e.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0f26126-R2-wm.jpg
#   inflating: /content/mitstates/release_dataset/images/weathered brass/ex0f4451-R2-wm.jpg
# ...
#   inflating: /content/mitstates/release_dataset/tests/adj apple/Fuji-Dry1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/Fuji_apple.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/GoldenDelicious__39861.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/Honeycrisp-Apple.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/POL_apple.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/Red_Apple.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/apple.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/apple20with20heart.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/apple_001.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/apple_2312343b.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/apple_8.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/apple_bite2.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/apples1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/eating-apples-extended-lifespan-test-animals-10-per-cent_183.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/free-photo-apple-853.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/gala-apple.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/maca_apple_vector.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj apple/organic-three-red-apple-backgrounds-powerpoint.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/64556.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/A000019_L.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AB1018_Gothic_Breastplate_Harness.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AE1446.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AR007BK_Black_Knight_Armor_Torso.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AR008-R_Torso.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AR008103_.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AR008_Sentinal_Clear.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AR00903_Italian_Knight_Blued_Finish_Logo.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AR1150003_Spanish_Knight-Torso-SA.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AR217A_Spaulders.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/AR900002-Torso-SA.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/Armor_2_by_Kuroi1nu.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/DragonscaleArmor.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/GAU-GN008.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/KHM_Wien_A_3_-_Armor_of_Roberto_da_Sanseverino_(d._1487).jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/Linwes_armor.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/Lion_Armor___Complete_by_Azmal2.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/MIN0653B_Miniature_Suit_of_Armor_Knight.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/RC_TE_Armor_2.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/Sentinel_Suit_or_Armor_Torso_SA-Logo.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/Sir_Christopher.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/WLA_metmuseum_Armor_of_Henry_II_of_France.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/Warder-armor-Female.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/White_Knight_Armor_SA-Logo.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/White_Knight_Armor_Torso_logo.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/armor.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/closed-salet-armor-6002.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/steampunk_golddd_d_by_steampunkoverlord-d32zp3j.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj armor/suit-of-armor1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/05_shopping_bag_a_spalla_pelle_taupe.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/8618_antiatoms-paper-bag-d23459876075.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Black-Togo-Leather-30cm-Birkin-Bag-with-Palladium-Hardware.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Bright-Red-Bag.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Brioni-Men-Large-Leather-Travel-Bag-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Coach-madison-op-art-sateen-abigail-shoulder-bag-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/CraftCoachBag_large.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Custom-handmade-Leather-Messenger-Bag_LRG.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Dior-Lady-Dior-bag-in-bright-red-leather-2.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Dior-Large-Lady-Dior-bag-in-red-leather-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Dior-Large-Miss-Dior-shopping-bag-in-black-leather-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Doctors-Bag-(021).jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/EVERYDAY_BABY_BAG_BROWN_FRONT.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Furla-Candy-Bag2.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Gucci-Large-Leather-Messenger-Bag-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Gucci-rania-top-handle-original-GG-canvas-top-handle-bag-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Lady-Bag-MY-8853-.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Louis-Vuitton-Lockit-Bag-2.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Louis-Vuitton-Olympe-Bag-In-Monogram-Canvas-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Misha20Bag.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/Overnight-Bag-mens.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/SwissGearBagNewImage_1371476085.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/TB0202_01b.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/aa_bag_in_bagorange_1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/bag1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/bag220_black_coffee_front_1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/bagcraze_celine_spring11_1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/birkin-bag.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/diaper-bag-disney-baby-photo-1800x1800-dcp-4018055562297.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/doctors-bag-by-shoestock-na-promo-por-r399-001.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/erwin-messenger-bag1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/f21bag03.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/gucci-for-unisef-sukey-bag-2010.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/gym-bag.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/hermes2Bbag2BHaut2Ba2BCourroie2BHelium.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/hermes_bag.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/hunter-main.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/jb6132_jute_uk_carry_bag_medium_luxury_low_res_2_2.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/leatherbag1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/mulberry-tony-croc-bag.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/notebook-bag-2.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/rogue-bush-sling-bag-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/shopping-bag-icon.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj bag/will-leather-bag.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/24inch-beach-ball-extralarge-209982.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/2630volley_ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/68.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/7734beach_ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/88S_Shiney_Stress_Ball_Blue.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/Beach-Ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/Cricket_ball_G26M.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/Gym-Ball-5.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/Gym-Ball-6.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/Happy_face_ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/Lax_ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/SC2085-499-barcelona-skills-ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/SS-SB001_Stress_Ball1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/Snooker_Touching_Ball_Blue.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/Soccer20ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/SuperBall_Mini_purple.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/SuperBall_purple.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/baseball_crop.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/bball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/beachball1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/chrome-ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/fama0034-gym_ball_65cm_blue_1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/globe-stress-ball--extralarge-57925.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/golf-ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/lolo_ball_-_rock_n_hopper.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/orange_ball_by_emmal27-d33jhac.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/pac-man-stress-ball-hi-res3.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/pilates_ball_power_pilates(1).jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/playground_ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/purple-exercise-ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/pvc-covered-foam-ball-blue__99898_zoom.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/red-christmas-ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/red-soccer-ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/soccer-ball-sxc.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/stability_ball_55cm-zm.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/tumbler_ball.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/vector-beach-ball-gn-psd-390361.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj ball/white20ball20220inch.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/2006_Ojiya_balloon_festival_011.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/24785_the-red-balloon-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/5thPutrajayaInternationalHotAirBalloonFiestaHotairballoonintheair.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Air-Balloon.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Albuquerque_BalloonFiesta.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Balloon_Festival_29_by_Dracoart_Stock.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Balloon_arch.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Balloon_free_image.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Ballooning-june-29-04-036.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Balloons1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Birthday-Balloons.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Color_Splash_Balloon_by_viseeu.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Green-Balloon20013A12.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Hot-Dubai-and-Hot-air-balloon.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Hot_air_balloon_with_hearts.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/InflatableBalloons.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Luftballong.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Red_White_Blue_Balloon_Stock_by_DavidBradbury.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/Yankee.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/albuquerque_international_balloon_fiesta-normal.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloon-940x626.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloon-time-peytons-birthday-010.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloon-vector-3.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloon.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloon001.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloon1big.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloon_photography_melbourne-1.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloon_wallpapers_13574_2560x1920.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloons.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/balloons_3.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/five-balloon-table-bouquet.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/g-cwow-balloon.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/hot-air-balloon-clark.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/img-20120901-00513.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/img_5993.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/metallic-blue-party-balloon-main-187-187.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/red_balloon.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/redballoon024.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/sapphire_blue.jpg
#   inflating: /content/mitstates/release_dataset/tests/adj balloon/seven-balloon-bouquet.jpg
# Dataset downloaded and extracted successfully!

# %%
import shutil
import os

# Source and destination directories
source_dir = "/content/mitstates/release_dataset"
destination_dir = "/content/data/mitstates"

# Ensure the destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Move all contents from source to destination
for item in os.listdir(source_dir):
    source_path = os.path.join(source_dir, item)
    destination_path = os.path.join(destination_dir, item)

    if os.path.isdir(source_path):
        shutil.move(source_path, destination_path)
    else:
        shutil.move(source_path, destination_path)

print(f"All files and directories moved from {source_dir} to {destination_dir}.")
# Out:
# All files and directories moved from /content/mitstates/release_dataset to /content/data/mitstates.

# %%
# !git clone https://github.com/ecom-research/ComposeAE.git
# Out:
# Cloning into 'ComposeAE'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 173 (delta 52), reused 48 (delta 48), pack-reused 114 (from 1)
# Receiving objects: 100% (173/173), 567.75 KiB | 1.71 MiB/s, done.
# Resolving deltas: 100% (100/100), done.

# %%
# Install Python 3.6
# !sudo apt-get update
# !sudo apt-get install python3.6
# Install TensorBoard
# !pip install tensorboard
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,196 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,226 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,755 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,469 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,364 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,516 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,481 kB]
# Fetched 16.4 MB in 4s (4,387 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libcasa-python3-6' for regex 'python3.6'
# Note, selecting 'libpython3.6-stdlib' for regex 'python3.6'
# Note, selecting 'python3.6-2to3' for regex 'python3.6'
# The following additional packages will be installed:
#   libcasa-casa6
# The following NEW packages will be installed:
#   libcasa-casa6 libcasa-python3-6
# 0 upgraded, 2 newly installed, 0 to remove and 52 not upgraded.
# Need to get 1,088 kB of archives.
# After this operation, 4,238 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcasa-casa6 amd64 3.4.0-2build1 [1,000 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcasa-python3-6 amd64 3.4.0-2build1 [88.2 kB]
# Fetched 1,088 kB in 2s (521 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libcasa-casa6:amd64.
# (Reading database ... 123633 files and directories currently installed.)
# Preparing to unpack .../libcasa-casa6_3.4.0-2build1_amd64.deb ...
# Unpacking libcasa-casa6:amd64 (3.4.0-2build1) ...
# Selecting previously unselected package libcasa-python3-6:amd64.
# Preparing to unpack .../libcasa-python3-6_3.4.0-2build1_amd64.deb ...
# Unpacking libcasa-python3-6:amd64 (3.4.0-2build1) ...
# Setting up libcasa-casa6:amd64 (3.4.0-2build1) ...
# Setting up libcasa-python3-6:amd64 (3.4.0-2build1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboard) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
import numpy as np

# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install cython
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (3.0.11)

# %%
# !pip install tensorboardX tqdm
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (24.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (4.25.5)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2

# %%
"""Class for text data."""
import string
import numpy as np
import torch

class SimpleVocab(object):

    def __init__(self):
        super(SimpleVocab, self).__init__()
        self.word2id = {}
        self.wordcount = {}
        self.word2id['<UNK>'] = 0
        self.wordcount['<UNK>'] = 9e9

    def tokenize_text(self, text):
        text = text.encode('ascii', 'ignore').decode('ascii')
        tokens = str(text).lower().translate(str.maketrans('', '', string.punctuation)).strip().split()
        return tokens

    def add_text_to_vocab(self, text):
        tokens = self.tokenize_text(text)
        for token in tokens:
            if token not in self.word2id:
                self.word2id[token] = len(self.word2id)
                self.wordcount[token] = 0
            self.wordcount[token] += 1

    def threshold_rare_words(self, wordcount_threshold=5):
        for w in self.word2id:
            if self.wordcount[w] < wordcount_threshold:
                self.word2id[w] = 0

    def encode_text(self, text):
        tokens = self.tokenize_text(text)
        x = [self.word2id.get(t, 0) for t in tokens]
        return x

    def get_size(self):
        return len(self.word2id)


class TextLSTMModel(torch.nn.Module):

    def __init__(self,
                 texts_to_build_vocab,
                 word_embed_dim=512,
                 lstm_hidden_dim=512):

        super(TextLSTMModel, self).__init__()

        self.vocab = SimpleVocab()
        for text in texts_to_build_vocab:
            self.vocab.add_text_to_vocab(text)
        vocab_size = self.vocab.get_size()

        self.word_embed_dim = word_embed_dim
        self.lstm_hidden_dim = lstm_hidden_dim
        self.embedding_layer = torch.nn.Embedding(vocab_size, word_embed_dim)
        self.lstm = torch.nn.LSTM(word_embed_dim, lstm_hidden_dim)
        self.fc_output = torch.nn.Sequential(
            torch.nn.Dropout(p=0.1),
            torch.nn.Linear(lstm_hidden_dim, lstm_hidden_dim),
        )

    def forward(self, x):
        """ input x: list of strings"""
        if type(x) is list:
            if type(x[0]) is str or type(x[0]) is unicode:
                x = [self.vocab.encode_text(text) for text in x]
        assert type(x) is list
        assert type(x[0]) is list
        assert type(x[0][0]) is int
        return self.forward_encoded_texts(x)

    def forward_encoded_texts(self, texts):
        # to tensor
        lengths = [len(t) for t in texts]
        itexts = torch.zeros((np.max(lengths), len(texts))).long()
        for i in range(len(texts)):
            itexts[:lengths[i], i] = torch.tensor(texts[i])

        # embed words
        itexts = torch.autograd.Variable(itexts).cuda()
        etexts = self.embedding_layer(itexts)

        # lstm
        lstm_output, _ = self.forward_lstm_(etexts)

        # get last output (using length)
        text_features = []
        for i in range(len(texts)):
            text_features.append(lstm_output[lengths[i] - 1, i, :])

        # output
        text_features = torch.stack(text_features)
        text_features = self.fc_output(text_features)
        return text_features

    def forward_lstm_(self, etexts):
        batch_size = etexts.shape[1]
        first_hidden = (torch.zeros(1, batch_size, self.lstm_hidden_dim),
                        torch.zeros(1, batch_size, self.lstm_hidden_dim))
        first_hidden = (first_hidden[0].cuda(), first_hidden[1].cuda())
        lstm_output, last_hidden = self.lstm(etexts, first_hidden)
        return lstm_output, last_hidden

# %%
"""Evaluates the retrieval model."""
import numpy as np
import torch
import random
from tqdm import tqdm as tqdm
from collections import OrderedDict


def fiq_test(opt, model, testset):
    model.eval()

    all_imgs = []
    all_queries = []
    all_target_captions = []
    all_target_ids = []

    imgs = []
    mods = []
    out = []

    for i in tqdm(range(len(testset))):
        torch.cuda.empty_cache()
        item = testset[i]
        imgs += [testset.get_img(item['source_img_id'])]

        all_target_captions += [item['target_caption']]
        all_target_ids += [item['target_image_name']]

        mods += [item['target_caption']]

        if len(imgs) >= opt.batch_size or i == len(testset) - 1:
            imgs = torch.stack(imgs).float()
            imgs = torch.autograd.Variable(imgs).cuda()

            dct_with_representations = model.compose_img_text(imgs.cuda(), mods)
            f = dct_with_representations["repres"].data.cpu().numpy()
            all_queries += [f]

            imgs = []
            mods = []

    all_queries = np.concatenate(all_queries)
    print("all_queries len:", len(all_queries))

    # compute all image features
    imgs = []
    for i, original_image_id in enumerate(tqdm(testset.all_imgs_from_cat)):
        imgs += [testset.get_img_from_split(original_image_id)]
        if len(imgs) >= opt.batch_size or i == len(testset.all_imgs_from_cat) - 1:
            imgs = torch.stack(imgs).float()
            imgs = torch.autograd.Variable(imgs).cuda()
            imgs = model.extract_img_feature(imgs.cuda()).data.cpu().numpy()

            all_imgs += [imgs]
            imgs = []

    all_imgs = np.concatenate(all_imgs)

    print("all_imgs len:", len(all_imgs))
    print("all_imgs_from_category len:", len(testset.all_imgs_from_cat))

    # feature normalization
    for i in range(all_queries.shape[0]):
        all_queries[i, :] /= np.linalg.norm(all_queries[i, :])
    for i in range(all_imgs.shape[0]):
        all_imgs[i, :] /= np.linalg.norm(all_imgs[i, :])

    sims = all_queries.dot(all_imgs.T)
    print("sims shape: ", sims.shape)

    nn_result = [np.argsort(-sims[i, :])[:150] for i in range(sims.shape[0])]  # take more to remove duplicates
    nn_result_ids = [[testset.all_imgs_from_cat[nn] for nn in nns] for nns in nn_result]

    filtered_ids = []
    for ranking_ids in nn_result_ids:
        filtered_id_50 = list(OrderedDict.fromkeys(ranking_ids))[:50]  # filter duplicates and preserve order
        filtered_ids.append(filtered_id_50)

    if opt.category_to_train == 'all':
        cats_recalls = {'dress': {'recall': 0.0, 'num': 0},
                        'shirt': {'recall': 0.0, 'num': 0},
                        'toptee': {'recall': 0.0, 'num': 0}}

        things = {}

        for i, target_caption in enumerate(all_target_captions):
            clothing = target_caption.split()[0]
            if clothing in things:
                things[clothing].append({'orig_index': i, 'target_caption': target_caption})
            else:
                things[clothing] = []
                things[clothing].append({'orig_index': i, 'target_caption': target_caption})

        cats_recalls['dress']['num'] = len(things['dress'])
        cats_recalls['shirt']['num'] = len(things['shirt'])
        cats_recalls['toptee']['num'] = len(things['toptee'])
    else:
        cats_recalls = {opt.category_to_train: {'recall': 0.0, 'num': 0}}
        cats_recalls[opt.category_to_train]['num'] = len(testset)

    for k in [1, 5, 10, 50, 100]:
        for i, nns in enumerate(filtered_ids):
            if all_target_ids[i] in nns[:k]:
                if opt.category_to_train == 'all':
                    cats_recalls[all_target_captions[i].split()[0]]['recall'] += 1
                else:
                    cats_recalls[opt.category_to_train]['recall'] += 1
        for cat in cats_recalls:
            cats_recalls[cat]['recall'] /= cats_recalls[cat]['num']
            out += [('recall_top' + str(k) + '_correct_' + cat, cats_recalls[cat]['recall'])]

    return out


def test(opt, model, testset):
    """Tests a model over the given testset."""
    model.eval()
    test_queries = testset.get_test_queries()

    all_imgs = []
    all_captions = []
    all_queries = []
    all_target_captions = []
    if test_queries:
        imgs = []
        mods = []
        for t in tqdm(test_queries):
            torch.cuda.empty_cache()
            imgs += [testset.get_img(t['source_img_id'])]
            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    mods += [t['mod']['str'] + " " + t["noun"]]
                else:
                    mods += [t['target_caption']]
            else:
                mods += [t['mod']['str']]

            if len(imgs) >= opt.batch_size or t is test_queries[-1]:
                if 'torch' not in str(type(imgs[0])):
                    imgs = [torch.from_numpy(d).float() for d in imgs]
                imgs = torch.stack(imgs).float()
                imgs = torch.autograd.Variable(imgs).cuda()
                dct_with_representations = model.compose_img_text(imgs.cuda(), mods)
                f = dct_with_representations["repres"].data.cpu().numpy()
                all_queries += [f]
                imgs = []
                mods = []
        all_queries = np.concatenate(all_queries)
        all_target_captions = [t['target_caption'] for t in test_queries]

        # compute all image features
        imgs = []
        for i in tqdm(range(len(testset.imgs))):
            imgs += [testset.get_img(i)]
            if len(imgs) >= opt.batch_size or i == len(testset.imgs) - 1:
                if 'torch' not in str(type(imgs[0])):
                    imgs = [torch.from_numpy(d).float() for d in imgs]
                imgs = torch.stack(imgs).float()
                imgs = torch.autograd.Variable(imgs).cuda()
                imgs = model.extract_img_feature(imgs.cuda()).data.cpu().numpy()

                all_imgs += [imgs]
                imgs = []
        all_imgs = np.concatenate(all_imgs)
        all_captions = [img['captions'][0] for img in testset.imgs]

    else:
        # use training queries to approximate training retrieval performance
        imgs0 = []
        imgs = []
        mods = []
        training_approx = 9600
        for i in range(training_approx):
            torch.cuda.empty_cache()
            item = testset[i]
            imgs += [item['source_img_data']]
            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    mods += [item['mod']['str'] + " " + item["noun"]]
                else:
                    mods += [item['target_caption']]
            else:
                mods += [item['mod']['str']]

            if len(imgs) >= opt.batch_size or i == training_approx:
                imgs = torch.stack(imgs).float()
                imgs = torch.autograd.Variable(imgs)
                dct_with_representations = model.compose_img_text(imgs.cuda(), mods)
                f = dct_with_representations["repres"].data.cpu().numpy()
                all_queries += [f]
                imgs = []
                mods = []
            imgs0 += [item['target_img_data']]
            if len(imgs0) >= opt.batch_size or i == training_approx:
                imgs0 = torch.stack(imgs0).float()
                imgs0 = torch.autograd.Variable(imgs0)
                imgs0 = model.extract_img_feature(imgs0.cuda()).data.cpu().numpy()
                all_imgs += [imgs0]
                imgs0 = []
            all_captions += [item['target_caption']]
            all_target_captions += [item['target_caption']]
        all_imgs = np.concatenate(all_imgs)
        all_queries = np.concatenate(all_queries)

    # feature normalization
    for i in range(all_queries.shape[0]):
        all_queries[i, :] /= np.linalg.norm(all_queries[i, :])
    for i in range(all_imgs.shape[0]):
        all_imgs[i, :] /= np.linalg.norm(all_imgs[i, :])

    # match test queries to target images, get nearest neighbors
    sims = all_queries.dot(all_imgs.T)
    if test_queries:
        for i, t in enumerate(test_queries):
            sims[i, t['source_img_id']] = -10e10  # remove query image
    nn_result = [np.argsort(-sims[i, :])[:110] for i in range(sims.shape[0])]

    # compute recalls
    out = []
    nn_result = [[all_captions[nn] for nn in nns] for nns in nn_result]
    for k in [1, 5, 10, 50, 100]:
        r = 0.0
        for i, nns in enumerate(nn_result):
            if all_target_captions[i] in nns[:k]:
                r += 1
        r /= len(nn_result)
        out += [('recall_top' + str(k) + '_correct_composition', r)]

        if opt.dataset == 'mitstates':
            r = 0.0
            for i, nns in enumerate(nn_result):
                if all_target_captions[i].split()[0] in [c.split()[0] for c in nns[:k]]:
                    r += 1
            r /= len(nn_result)
            out += [('recall_top' + str(k) + '_correct_adj', r)]

            r = 0.0
            for i, nns in enumerate(nn_result):
                if all_target_captions[i].split()[1] in [c.split()[1] for c in nns[:k]]:
                    r += 1
            r /= len(nn_result)
            out += [('recall_top' + str(k) + '_correct_noun', r)]

    return out

# %%
"""Metric learning functions.

Codes are modified from:
https://github.com/lugiavn/generalization-dml/blob/master/nams.py
"""

import numpy as np
import torch
import torchvision


def pairwise_distances(x, y=None):
  """
    Input: x is a Nxd matrix
           y is an optional Mxd matirx
    Output: dist is a NxM matrix where dist[i,j] is the square norm between
    x[i,:] and y[j,:]
            if y is not given then use 'y=x'.
    i.e. dist[i,j] = ||x[i,:]-y[j,:]||^2
    source:
    https://discuss.pytorch.org/t/efficient-distance-matrix-computation/9065/2
    """
  x_norm = (x**2).sum(1).view(-1, 1)
  if y is not None:
    y_t = torch.transpose(y, 0, 1)
    y_norm = (y**2).sum(1).view(1, -1)
  else:
    y_t = torch.transpose(x, 0, 1)
    y_norm = x_norm.view(1, -1)

  dist = x_norm + y_norm - 2.0 * torch.mm(x, y_t)
  # Ensure diagonal is zero if x=y
  # if y is None:
  #     dist = dist - torch.diag(dist.diag)
  return torch.clamp(dist, 0.0, np.inf)


import torch
import numpy as np

# Updated version of MyTripletLossFunc using the new static method style.
class MyTripletLossFunc(torch.autograd.Function):

    @staticmethod
    def forward(ctx, features, triplets):
        # Save tensors for backward pass
        ctx.save_for_backward(features)
        ctx.triplets = triplets

        # Compute pairwise distances
        distances = pairwise_distances(features).cpu().numpy()
        ctx.distances = distances

        # Compute the loss
        loss = 0.0
        triplet_count = 0.0
        correct_count = 0.0
        for i, j, k in triplets:
            w = 1.0
            triplet_count += w
            loss += w * np.log(1 + np.exp(distances[i, j] - distances[i, k]))
            if distances[i, j] < distances[i, k]:
                correct_count += 1

        loss /= triplet_count
        return torch.FloatTensor((loss,))

    @staticmethod
    def backward(ctx, grad_output):
        # Retrieve saved tensors
        features, = ctx.saved_tensors
        triplets = ctx.triplets
        features_np = features.cpu().numpy()

        # Initialize gradients
        grad_features = features.clone() * 0.0
        grad_features_np = grad_features.cpu().numpy()

        # Compute gradients
        for i, j, k in triplets:
            w = 1.0
            f = 1.0 - 1.0 / (1.0 + np.exp(ctx.distances[i, j] - ctx.distances[i, k]))
            grad_features_np[i, :] += w * f * (features_np[i, :] - features_np[j, :]) / len(triplets)
            grad_features_np[j, :] += w * f * (features_np[j, :] - features_np[i, :]) / len(triplets)
            grad_features_np[i, :] += -w * f * (features_np[i, :] - features_np[k, :]) / len(triplets)
            grad_features_np[k, :] += -w * f * (features_np[k, :] - features_np[i, :]) / len(triplets)

        # Convert gradients back to tensor
        for i in range(features_np.shape[0]):
            grad_features[i, :] = torch.from_numpy(grad_features_np[i, :])

        # Scale by the gradient from the output
        grad_features *= float(grad_output.data[0])
        return grad_features, None  # None for triplets, as it's not a tensor

# TripletLoss wrapper for using the custom loss in a model
class TripletLoss(torch.nn.Module):
    """Class for the triplet loss."""
    def __init__(self, pre_layer=None):
        super(TripletLoss, self).__init__()
        self.pre_layer = pre_layer

    def forward(self, x, triplets):
        if self.pre_layer is not None:
            x = self.pre_layer(x)
        loss = MyTripletLossFunc.apply(x, triplets)
        return loss

class NormalizationLayer(torch.nn.Module):
  """Class for normalization layer."""
  def __init__(self, normalize_scale=1.0, learn_scale=True):
    super(NormalizationLayer, self).__init__()
    self.norm_s = float(normalize_scale)
    if learn_scale:
      self.norm_s = torch.nn.Parameter(torch.FloatTensor((self.norm_s,)))

  def forward(self, x):
    features = self.norm_s * x / torch.norm(x, dim=1, keepdim=True).expand_as(x)
    return features

# %%
"""Great things."""

"""Provides data for training and testing."""
import numpy as np
import PIL
import skimage
import torch
import json
import torch.utils.data
import torchvision
import warnings
import random


class BaseDataset(torch.utils.data.Dataset):
    """Base class for a dataset."""

    def __init__(self):
        super(BaseDataset, self).__init__()
        self.imgs = []
        self.test_queries = []

    def get_loader(self,
                   batch_size,
                   shuffle=False,
                   drop_last=False,
                   num_workers=0):
        return torch.utils.data.DataLoader(
            self,
            batch_size=batch_size,
            shuffle=shuffle,
            num_workers=num_workers,
            drop_last=drop_last,
            collate_fn=lambda i: i)

    def get_test_queries(self):
        return self.test_queries

    def get_all_texts(self):
        raise NotImplementedError

    def __getitem__(self, idx):
        return self.generate_random_query_target()

    def generate_random_query_target(self):
        raise NotImplementedError

    def get_img(self, idx, raw_img=False):
        raise NotImplementedError

class Fashion200k(BaseDataset):
    """Fashion200k dataset."""

    def __init__(self, path, split='train', transform=None):
        super(Fashion200k, self).__init__()

        self.split = split
        self.transform = transform
        self.img_path = path + '/'

        # get label files for the split
        label_path = path + '/labels/'
        from os import listdir
        from os.path import isfile
        from os.path import join
        label_files = [
            f for f in listdir(label_path) if isfile(join(label_path, f))
        ]
        label_files = [f for f in label_files if split in f]

        # read image info from label files
        self.imgs = []

        def caption_post_process(s):
            return s.strip().replace('.',
                                     'dotmark').replace('?', 'questionmark').replace(
                '&', 'andmark').replace('*', 'starmark')

        for filename in label_files:
            print('read ' + filename)
            with open(label_path + '/' + filename) as f:
                lines = f.readlines()
            for line in lines:
                line = line.split('	')
                img = {
                    'file_path': line[0],
                    'detection_score': line[1],
                    'captions': [caption_post_process(line[2])],
                    'split': split,
                    'modifiable': False
                }
                self.imgs += [img]
        print('Fashion200k:', len(self.imgs), 'images')

        # generate query for training or testing
        if split == 'train':
            self.caption_index_init_()
        else:
            self.generate_test_queries_()

    def get_different_word(self, source_caption, target_caption):
        source_words = source_caption.split()
        target_words = target_caption.split()
        for source_word in source_words:
            if source_word not in target_words:
                break
        for target_word in target_words:
            if target_word not in source_words:
                break
        mod_str = 'replace ' + source_word + ' with ' + target_word
        return source_word, target_word, mod_str

    def generate_test_queries_(self):
        file2imgid = {}
        for i, img in enumerate(self.imgs):
            file2imgid[img['file_path']] = i
        with open(self.img_path + '/test_queries.txt') as f:
            lines = f.readlines()
        self.test_queries = []
        for line in lines:
            source_file, target_file = line.split()
            idx = file2imgid[source_file]
            target_idx = file2imgid[target_file]
            source_caption = self.imgs[idx]['captions'][0]
            target_caption = self.imgs[target_idx]['captions'][0]
            source_word, target_word, mod_str = self.get_different_word(
                source_caption, target_caption)
            self.test_queries += [{
                'source_img_id': idx,
                'source_caption': source_caption,
                'target_caption': target_caption,
                'mod': {
                    'str': mod_str
                }
            }]

    def caption_index_init_(self):
        """ index caption to generate training query-target example on the fly later"""

        # index caption 2 caption_id and caption 2 image_ids
        caption2id = {}
        id2caption = {}
        caption2imgids = {}
        for i, img in enumerate(self.imgs):
            for c in img['captions']:
                if c not in caption2id:
                    id2caption[len(caption2id)] = c
                    caption2id[c] = len(caption2id)
                    caption2imgids[c] = []
                caption2imgids[c].append(i)
        self.caption2imgids = caption2imgids
        print(len(caption2imgids), 'unique cations')

        # parent captions are 1-word shorter than their children
        parent2children_captions = {}
        for c in caption2id.keys():
            for w in c.split():
                p = c.replace(w, '')
                p = p.replace('  ', ' ').strip()
                if p not in parent2children_captions:
                    parent2children_captions[p] = []
                if c not in parent2children_captions[p]:
                    parent2children_captions[p].append(c)
        self.parent2children_captions = parent2children_captions

        # identify parent captions for each image
        for img in self.imgs:
            img['modifiable'] = False
            img['parent_captions'] = []
        for p in parent2children_captions:
            if len(parent2children_captions[p]) >= 2:
                for c in parent2children_captions[p]:
                    for imgid in caption2imgids[c]:
                        self.imgs[imgid]['modifiable'] = True
                        self.imgs[imgid]['parent_captions'] += [p]
        num_modifiable_imgs = 0
        for img in self.imgs:
            if img['modifiable']:
                num_modifiable_imgs += 1
        print('Modifiable images', num_modifiable_imgs)

    def caption_index_sample_(self, idx):
        while not self.imgs[idx]['modifiable']:
            idx = np.random.randint(0, len(self.imgs))

        # find random target image (same parent)
        img = self.imgs[idx]
        while True:
            p = random.choice(img['parent_captions'])
            c = random.choice(self.parent2children_captions[p])
            if c not in img['captions']:
                break
        target_idx = random.choice(self.caption2imgids[c])

        # find the word difference between query and target (not in parent caption)
        source_caption = self.imgs[idx]['captions'][0]
        target_caption = self.imgs[target_idx]['captions'][0]
        source_word, target_word, mod_str = self.get_different_word(
            source_caption, target_caption)
        return idx, target_idx, source_word, target_word, mod_str

    def get_all_texts(self):
        texts = []
        for img in self.imgs:
            for c in img['captions']:
                texts.append(c)
        return texts

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        idx, target_idx, source_word, target_word, mod_str = self.caption_index_sample_(
            idx)
        out = {}
        out['source_img_id'] = idx
        out['source_img_data'] = self.get_img(idx)
        out['source_caption'] = self.imgs[idx]['captions'][0]
        out['target_img_id'] = target_idx
        out['target_img_data'] = self.get_img(target_idx)
        out['target_caption'] = self.imgs[target_idx]['captions'][0]
        out['mod'] = {'str': mod_str}
        return out

    def get_img(self, idx, raw_img=False):
        img_path = self.img_path + self.imgs[idx]['file_path']
        with open(img_path, 'rb') as f:
            img = PIL.Image.open(f)
            img = img.convert('RGB')
        if raw_img:
            return img
        if self.transform:
            img = self.transform(img)
        return img

class MITStates(BaseDataset):
    """MITStates dataset."""
    def __init__(self, path, split='train', transform=None):
        super(MITStates, self).__init__()
        self.path = path
        self.transform = transform
        self.split = split

        self.imgs = []
        test_nouns = [
            u'armor', u'bracelet', u'bush', u'camera', u'candy', u'castle',
            u'ceramic', u'cheese', u'clock', u'clothes', u'coffee', u'fan', u'fig',
            u'fish', u'foam', u'forest', u'fruit', u'furniture', u'garden', u'gate',
            u'glass', u'horse', u'island', u'laptop', u'lead', u'lightning',
            u'mirror', u'orange', u'paint', u'persimmon', u'plastic', u'plate',
            u'potato', u'road', u'rubber', u'sand', u'shell', u'sky', u'smoke',
            u'steel', u'stream', u'table', u'tea', u'tomato', u'vacuum', u'wax',
            u'wheel', u'window', u'wool'
        ]

        from os import listdir
        for f in listdir(path + '/images'):
            if ' ' not in f:
                continue
            adj, noun = f.split()
            if adj == 'adj':
                continue
            if split == 'train' and noun in test_nouns:
                continue
            if split == 'test' and noun not in test_nouns:
                continue

            for file_path in listdir(path + '/images/' + f):
                assert (file_path.endswith('jpg'))
                self.imgs += [{
                    'file_path': path + '/images/' + f + '/' + file_path,
                    'captions': [f],
                    'adj': adj,
                    'noun': noun
                }]

        self.caption_index_init_()
        if split == 'test':
            self.generate_test_queries_()

    def get_all_texts(self):
        texts = []
        for img in self.imgs:
            texts += img['captions']
        return texts

    def __getitem__(self, idx):
        try:
            self.saved_item
        except:
            self.saved_item = None
        if self.saved_item is None:
            while True:
                idx, target_idx1 = self.caption_index_sample_(idx)
                idx, target_idx2 = self.caption_index_sample_(idx)
                if self.imgs[target_idx1]['adj'] != self.imgs[target_idx2]['adj']:
                    break
            idx, target_idx = [idx, target_idx1]
            self.saved_item = [idx, target_idx2]
        else:
            idx, target_idx = self.saved_item
            self.saved_item = None

        mod_str = self.imgs[target_idx]['adj']

        return {
            'source_img_id': idx,
            'source_img_data': self.get_img(idx),
            'source_caption': self.imgs[idx]['captions'][0],
            'target_img_id': target_idx,
            'target_img_data': self.get_img(target_idx),
            'noun': self.imgs[idx]['noun'],
            'target_caption': self.imgs[target_idx]['captions'][0],
            'mod': {
                'str': mod_str
            }
        }

    def caption_index_init_(self):
        self.caption2imgids = {}
        self.noun2adjs = {}
        for i, img in enumerate(self.imgs):
            cap = img['captions'][0]
            adj = img['adj']
            noun = img['noun']
            if cap not in self.caption2imgids.keys():
                self.caption2imgids[cap] = []
            if noun not in self.noun2adjs.keys():
                self.noun2adjs[noun] = []
            self.caption2imgids[cap].append(i)
            if adj not in self.noun2adjs[noun]:
                self.noun2adjs[noun].append(adj)
        for noun, adjs in self.noun2adjs.items():
            assert len(adjs) >= 2

    def caption_index_sample_(self, idx):
        noun = self.imgs[idx]['noun']
        # adj = self.imgs[idx]['adj']
        target_adj = random.choice(self.noun2adjs[noun])
        target_caption = target_adj + ' ' + noun
        target_idx = random.choice(self.caption2imgids[target_caption])
        return idx, target_idx

    def generate_test_queries_(self):
        self.test_queries = []
        for idx, img in enumerate(self.imgs):
            adj = img['adj']
            noun = img['noun']
            for target_adj in self.noun2adjs[noun]:
                if target_adj != adj:
                    mod_str = target_adj
                    self.test_queries += [{
                        'source_img_id': idx,
                        'source_caption': adj + ' ' + noun,
                        'target_caption': target_adj + ' ' + noun,
                        'noun': self.imgs[idx]['noun'],
                        'mod': {
                            'str': mod_str
                        }
                    }]
        print(len(self.test_queries), 'test queries')

    def __len__(self):
        return len(self.imgs)

    def get_img(self, idx, raw_img=False):
        img_path = self.imgs[idx]['file_path']
        with open(img_path, 'rb') as f:
            img = PIL.Image.open(f)
            img = img.convert('RGB')
        if raw_img:
            return img
        if self.transform:
            img = self.transform(img)
        return img

class FashionIQ(BaseDataset):
    """FashionIQ dataset."""

    def __init__(self, path, split='train', cat_type='all', transform=None):
        super(FashionIQ, self).__init__()
        self.path = path
        self.transform = transform
        self.split = split
        self.imgs = []

        caps_path = path + "captions/"

        train_caps = ["cap.dress.train.json",
                      "cap.shirt.train.json",
                      "cap.toptee.train.json"]

        val_caps = ["cap.dress.val.json",
                    "cap.shirt.val.json",
                    "cap.toptee.val.json"]

        # load all pool of images
        if cat_type == 'all':
            self.all_imgs_from_cat = []
            for c in ['dress', 'shirt', 'toptee']:
                with open(path + 'image_splits/split.' + c + '.' + split + '.json') as f:
                    self.all_imgs_from_cat += json.load(f)

        #  load splits
        caps = []
        if split == 'val':
            print("Using " + cat_type + " val data")
            if cat_type == 'all':
                caps = val_caps
            else:
                caps = ["cap." + cat_type + ".val.json"]
                with open(path + 'image_splits/split.' + cat_type + '.val.json') as f:
                    self.all_imgs_from_cat = json.load(f)
        elif split == 'train':
            print("Using " + cat_type + " train data")
            if cat_type == 'all':
                caps = train_caps
            else:
                caps = ["cap." + cat_type + ".train.json"]
                with open(path + 'image_splits/split.' + cat_type + '.train.json') as f:
                    self.all_imgs_from_cat = json.load(f)

        for cat in caps:
            with open(caps_path + cat) as f:
                cap2smth = json.load(f)
            cat_name = cat.split('.')[1]
            for idx, cap in enumerate(cap2smth):
                if cat_type == 'all':
                    captions = (cat_name + ' ' + ' and it '.join(cap['captions'])).lower()
                else:
                    captions = ' '.join(cap['captions']).lower()
                d = {
                    'source_image_path': path + 'all_imgs/' + cap['candidate'] + '.jpg',
                    'captions': captions,
                    'original_captions': cap['captions'],
                    'candidate_image_name': cap['candidate'],
                    'source_img_id': idx,
                }
                if split != 'real_test':
                    d['target_image_path'] = path + 'all_imgs/' + cap['target'] + '.jpg'
                    d['target_image_name'] = cap['target']

                self.imgs += [d]

    def get_all_texts(self):
        texts = []
        for img in self.imgs:
            texts += img['captions']
        return texts

    def __getitem__(self, idx):
        d = {
            'source_img_id': idx,
            'source_img_data': self.get_img(idx, if_target=False),
            'target_caption': self.imgs[idx]['captions'],
            'original_captions': self.imgs[idx]['original_captions'],
            'candidate_image_name': self.imgs[idx]['candidate_image_name'],
            'mod': {
                'str': self.imgs[idx]['captions']
            }
        }

        if self.split != 'real_test':
            d['target_image_name'] = self.imgs[idx]['target_image_name']
            d['target_img_data'] = self.get_img(idx, if_target=True)

        return d

    def __len__(self):
        return len(self.imgs)

    def get_img(self, idx, if_target=False):
        if if_target:
            img_path = self.imgs[idx]['target_image_path']
        else:
            img_path = self.imgs[idx]['source_image_path']

        with open(img_path, 'rb') as f:
            img = PIL.Image.open(f)
            img = img.convert('RGB')

        if self.transform:
            img = self.transform(img)

        return img

    def get_img_from_split(self, original_image_id):
        img_path = self.path + 'all_imgs/' + original_image_id + '.jpg'

        with open(img_path, 'rb') as f:
            img = PIL.Image.open(f)
            img = img.convert('RGB')

        if self.transform:
            img = self.transform(img)

        return img

# %%
"""Models for Text and Image Composition."""

import numpy as np
import torch
import torchvision
import torch.nn.functional as F

from torch.autograd import Variable
from transformers import BertTokenizer, BertModel
import torch
import torchvision
import torch.nn.functional as F

class ConCatModule(torch.nn.Module):

    def __init__(self):
        super(ConCatModule, self).__init__()

    def forward(self, x):
        x = torch.cat(x, 1)

        return x

class ImgTextCompositionBase(torch.nn.Module):
    """Base class for image + text composition."""

    def __init__(self):
        super().__init__()
        self.normalization_layer = NormalizationLayer(
            normalize_scale=4.0, learn_scale=True)
        self.soft_triplet_loss = TripletLoss()

    def extract_img_feature(self, imgs):
        raise NotImplementedError

    def extract_text_feature(self, text_query, use_bert):
        raise NotImplementedError

    def compose_img_text(self, imgs, text_query):
        raise NotImplementedError

    def compute_loss(self,
                     imgs_query,
                     text_query,
                     imgs_target,
                     soft_triplet_loss=True):
        dct_with_representations = self.compose_img_text(imgs_query, text_query)
        composed_source_image = self.normalization_layer(dct_with_representations["repres"])
        target_img_features_non_norm = self.extract_img_feature(imgs_target)
        target_img_features = self.normalization_layer(target_img_features_non_norm)
        assert (composed_source_image.shape[0] == target_img_features.shape[0] and
                composed_source_image.shape[1] == target_img_features.shape[1])
        # Get Rot_Sym_Loss
        if self.name == 'composeAE':
            CONJUGATE = Variable(torch.cuda.FloatTensor(32, 1).fill_(-1.0), requires_grad=False)
            conjugate_representations = self.compose_img_text_features(target_img_features_non_norm, dct_with_representations["text_features"], CONJUGATE)
            composed_target_image = self.normalization_layer(conjugate_representations["repres"])
            source_img_features = self.normalization_layer(dct_with_representations["img_features"]) #img1
            if soft_triplet_loss:
                dct_with_representations ["rot_sym_loss"]= \
                    self.compute_soft_triplet_loss_(composed_target_image,source_img_features)
            else:
                dct_with_representations ["rot_sym_loss"]= \
                    self.compute_batch_based_classification_loss_(composed_target_image,
                                                              source_img_features)
        else: # tirg, RealSpaceConcatAE etc
            dct_with_representations ["rot_sym_loss"] = 0

        if soft_triplet_loss:
            return self.compute_soft_triplet_loss_(composed_source_image,
                                                   target_img_features), dct_with_representations
        else:
            return self.compute_batch_based_classification_loss_(composed_source_image,
                                                                 target_img_features), dct_with_representations

    def compute_soft_triplet_loss_(self, mod_img1, img2):
        triplets = []
        labels = list(range(mod_img1.shape[0])) + list(range(img2.shape[0]))
        for i in range(len(labels)):
            triplets_i = []
            for j in range(len(labels)):
                if labels[i] == labels[j] and i != j:
                    for k in range(len(labels)):
                        if labels[i] != labels[k]:
                            triplets_i.append([i, j, k])
            np.random.shuffle(triplets_i)
            triplets += triplets_i[:3]
        assert (triplets and len(triplets) < 2000)
        return self.soft_triplet_loss(torch.cat([mod_img1, img2]), triplets)

    def compute_batch_based_classification_loss_(self, mod_img1, img2):
        x = torch.mm(mod_img1, img2.transpose(0, 1))
        labels = torch.tensor(range(x.shape[0])).long()
        labels = torch.autograd.Variable(labels).cuda()
        return F.cross_entropy(x, labels)


class ImgEncoderTextEncoderBase(ImgTextCompositionBase):
    """Base class for image and text encoder."""

    def __init__(self, text_query, image_embed_dim, text_embed_dim, use_bert, name):
        super().__init__()

        # Image model (ResNet18)
        img_model = torchvision.models.resnet18(pretrained=True)
        self.name = name

        class GlobalAvgPool2d(torch.nn.Module):
            def forward(self, x):
                return F.adaptive_avg_pool2d(x, (1, 1))

        img_model.avgpool = GlobalAvgPool2d()
        img_model.fc = torch.nn.Sequential(torch.nn.Linear(image_embed_dim, image_embed_dim))
        self.img_model = img_model

        # Text model: Using Hugging Face BERT or a custom LSTM model
        self.use_bert = use_bert

        if self.use_bert:
            # Load BERT model and tokenizer from Hugging Face
            self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
            self.text_model = BertModel.from_pretrained('bert-base-uncased')
            self.text_embed_dim = text_embed_dim
        else:
            # Fallback: Your custom LSTM model
            self.text_model = TextLSTMModel(
                texts_to_build_vocab=text_query,
                word_embed_dim=text_embed_dim,
                lstm_hidden_dim=text_embed_dim
            )

    def extract_img_feature(self, imgs):
        # Forward pass through the image model
        return self.img_model(imgs)

    def extract_text_feature(self, text_query, use_bert):
        if self.use_bert:
            # Tokenize the input text
            inputs = self.tokenizer(text_query, padding=True, truncation=True, return_tensors="pt")
            inputs = {name: tensor.cuda() for name, tensor in inputs.items()}

            # Get BERT embeddings (using the [CLS] token's representation)
            with torch.no_grad():
                outputs = self.text_model(**inputs)

            # Extract the embeddings of the [CLS] token
            text_features = outputs.last_hidden_state[:, 0, :]  # [batch_size, hidden_size]
            return text_features
        else:
            # Fallback to LSTM model for text encoding
            return self.text_model(text_query)



class TIRG(ImgEncoderTextEncoderBase):
    """The TIRG model.

    The method is described in
    Nam Vo, Lu Jiang, Chen Sun, Kevin Murphy, Li-Jia Li, Li Fei-Fei, James Hays.
    "Composing Text and Image for Image Retrieval - An Empirical Odyssey"
    CVPR 2019. arXiv:1812.07119
    """

    def __init__(self, text_query, image_embed_dim, text_embed_dim, use_bert, name):
        super().__init__(text_query, image_embed_dim, text_embed_dim, use_bert, name)

        self.a = torch.nn.Parameter(torch.tensor([1.0, 10.0, 1.0, 1.0]))
        self.use_bert = use_bert

        merged_dim = image_embed_dim + text_embed_dim

        self.gated_feature_composer = torch.nn.Sequential(
            ConCatModule(),
            torch.nn.BatchNorm1d(merged_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(merged_dim, image_embed_dim)
        )

        self.res_info_composer = torch.nn.Sequential(
            ConCatModule(),
            torch.nn.BatchNorm1d(merged_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(merged_dim, merged_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(merged_dim, image_embed_dim)
        )

    def compose_img_text(self, imgs, text_query):
        img_features = self.extract_img_feature(imgs)
        text_features = self.extract_text_feature(text_query, self.use_bert)

        return self.compose_img_text_features(img_features, text_features)

    def compose_img_text_features(self, img_features, text_features):
        f1 = self.gated_feature_composer((img_features, text_features))
        f2 = self.res_info_composer((img_features, text_features))
        f = F.sigmoid(f1) * img_features * self.a[0] + f2 * self.a[1]

        dct_with_representations = {"repres": f}
        return dct_with_representations

class ComplexProjectionModule(torch.nn.Module):

    def __init__(self, image_embed_dim =512, text_embed_dim = 768):
        super().__init__()
        self.bert_features = torch.nn.Sequential(
            torch.nn.BatchNorm1d(text_embed_dim),
            torch.nn.Linear(text_embed_dim, image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim)
        )
        self.image_features = torch.nn.Sequential(
            torch.nn.BatchNorm1d(image_embed_dim),
            torch.nn.Linear(image_embed_dim, image_embed_dim),
            torch.nn.Dropout(p=0.5),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim),
        )

    def forward(self, x):
        x1 = self.image_features(x[0])
        x2 = self.bert_features(x[1])
        # default value of CONJUGATE is 1. Only for rotationally symmetric loss value is -1.
        # which results in the CONJUGATE of text features in the complex space
        CONJUGATE = x[2]
        num_samples = x[0].shape[0]
        CONJUGATE = CONJUGATE[:num_samples]
        delta = x2  # text as rotation
        re_delta = torch.cos(delta)
        im_delta = CONJUGATE * torch.sin(delta)

        re_score = x1 * re_delta
        im_score = x1 * im_delta

        concat_x = torch.cat([re_score, im_score], 1)
        x0copy = x[0].unsqueeze(1)
        x1 = x1.unsqueeze(1)
        x2 = x2.unsqueeze(1)
        re_score = re_score.unsqueeze(1)
        im_score = im_score.unsqueeze(1)

        return concat_x, x1, x2, x0copy, re_score, im_score

class LinearMapping(torch.nn.Module):
    """
    This is linear mapping to image space. rho(.)
    """

    def __init__(self, image_embed_dim =512):
        super().__init__()
        self.mapping = torch.nn.Sequential(
            torch.nn.BatchNorm1d(2 * image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(2 * image_embed_dim, image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim)
        )

    def forward(self, x):
        theta_linear = self.mapping(x[0])
        return theta_linear
class ConvMapping(torch.nn.Module):
    """
    This is convoultional mapping to image space. rho_conv(.)
    """

    def __init__(self, image_embed_dim =512):
        super().__init__()
        self.mapping = torch.nn.Sequential(
            torch.nn.BatchNorm1d(2 * image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(2 * image_embed_dim, image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim)
        )
        # in_channels, output channels
        self.conv = torch.nn.Conv1d(5, 64, kernel_size=3, padding=1)
        self.adaptivepooling = torch.nn.AdaptiveMaxPool1d(16)

    def forward(self, x):
        concat_features = torch.cat(x[1:], 1)
        concat_x = self.conv(concat_features)
        concat_x = self.adaptivepooling(concat_x)
        final_vec = concat_x.reshape((concat_x.shape[0], 1024))
        theta_conv = self.mapping(final_vec)
        return theta_conv

class ComposeAE(ImgEncoderTextEncoderBase):
    """The ComposeAE model.

    The method is described in
    Muhammad Umer Anwaar, Egor Labintcev and Martin Kleinsteuber.
    ``Compositional Learning of Image-Text Query for Image Retrieval"
    arXiv:2006.11149
    """

    def __init__(self, text_query, image_embed_dim, text_embed_dim, use_bert, name):
        super().__init__(text_query, image_embed_dim, text_embed_dim, use_bert, name)
        self.a = torch.nn.Parameter(torch.tensor([1.0, 10.0, 1.0, 1.0]))
        self.use_bert = use_bert

        # merged_dim = image_embed_dim + text_embed_dim

        self.encoderLinear = torch.nn.Sequential(
            ComplexProjectionModule(),
            LinearMapping()
        )
        self.encoderWithConv = torch.nn.Sequential(
            ComplexProjectionModule(),
            ConvMapping()
        )
        self.decoder = torch.nn.Sequential(
            torch.nn.BatchNorm1d(image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim)
        )
        self.txtdecoder = torch.nn.Sequential(
            torch.nn.BatchNorm1d(image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, text_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(text_embed_dim, text_embed_dim)
        )

    def compose_img_text(self, imgs, text_query):
        img_features = self.extract_img_feature(imgs)
        text_features = self.extract_text_feature(text_query, self.use_bert)

        return self.compose_img_text_features(img_features, text_features)

    def compose_img_text_features(self, img_features, text_features, CONJUGATE = Variable(torch.cuda.FloatTensor(32, 1).fill_(1.0), requires_grad=False)):
        theta_linear = self.encoderLinear((img_features, text_features, CONJUGATE))
        theta_conv = self.encoderWithConv((img_features, text_features, CONJUGATE))
        theta = theta_linear * self.a[1] + theta_conv * self.a[0]

        dct_with_representations = {"repres": theta,
                                    "repr_to_compare_with_source": self.decoder(theta),
                                    "repr_to_compare_with_mods": self.txtdecoder(theta),
                                    "img_features": img_features,
                                    "text_features": text_features
                                    }

        return dct_with_representations

class RealConCatModule(torch.nn.Module):

    def __init__(self):
        super().__init__()

    def forward(self, x):
        concat_x = torch.cat(x, -1)
        return concat_x

class RealLinearMapping(torch.nn.Module):
    """
    This is linear mapping from real space to image space.
    """

    def __init__(self, image_embed_dim =512, text_embed_dim= 768):
        super().__init__()
        self.mapping = torch.nn.Sequential(
            torch.nn.BatchNorm1d(text_embed_dim + image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(text_embed_dim + image_embed_dim, image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim)
        )

    def forward(self, x):
        theta_linear = self.mapping(x)
        return theta_linear

class RealConvMapping(torch.nn.Module):
    """
    This is convoultional mapping from Real space to image space.
    """

    def __init__(self, image_embed_dim =512, text_embed_dim= 768):
        super().__init__()
        self.mapping = torch.nn.Sequential(
            torch.nn.BatchNorm1d(text_embed_dim + image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(text_embed_dim + image_embed_dim, image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim)
        )
        # in_channels, output channels
        self.conv1 = torch.nn.Conv1d(1, 64, kernel_size=3, padding=1)
        self.adaptivepooling = torch.nn.AdaptiveMaxPool1d(20)

    def forward(self, x):
        concat_x = self.conv1(x.unsqueeze(1))
        concat_x = self.adaptivepooling(concat_x)
        final_vec = concat_x.reshape((concat_x.shape[0], 1280))
        theta_conv = self.mapping(final_vec)
        return theta_conv

class RealSpaceConcatAE(ImgEncoderTextEncoderBase):
    """The RealSpaceConcatAE model.

    The method  in ablation study Table 5 (Concat in real space)
    Muhammad Umer Anwaar, Egor Labintcev and Martin Kleinsteuber.
    ``Compositional Learning of Image-Text Query for Image Retrieval"
    arXiv:2006.11149
    """

    def __init__(self, text_query, image_embed_dim, text_embed_dim, use_bert, name):
        super().__init__(text_query, image_embed_dim, text_embed_dim, use_bert, name)
        self.a = torch.nn.Parameter(torch.tensor([1.0, 10.0, 1.0, 1.0]))
        self.use_bert = use_bert

        # merged_dim = image_embed_dim + text_embed_dim

        self.encoderLinear = torch.nn.Sequential(
            RealConCatModule(),
            RealLinearMapping()
        )
        self.encoderWithConv = torch.nn.Sequential(
            RealConCatModule(),
            RealConvMapping()
        )
        self.decoder = torch.nn.Sequential(
            torch.nn.BatchNorm1d(image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, image_embed_dim)
        )
        self.txtdecoder = torch.nn.Sequential(
            torch.nn.BatchNorm1d(image_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(image_embed_dim, text_embed_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(text_embed_dim, text_embed_dim)
        )

    def compose_img_text(self, imgs, text_query):
        img_features = self.extract_img_feature(imgs)
        text_features = self.extract_text_feature(text_query, self.use_bert)

        return self.compose_img_text_features(img_features, text_features)

    def compose_img_text_features(self, img_features, text_features):
        theta_linear = self.encoderLinear((img_features, text_features))
        theta_conv = self.encoderWithConv((img_features, text_features))
        theta = theta_linear * self.a[1] + theta_conv * self.a[0]

        dct_with_representations = {"repres": theta,
                                    "repr_to_compare_with_source": self.decoder(theta),
                                    "repr_to_compare_with_mods": self.txtdecoder(theta),
                                    "img_features": img_features,
                                    "text_features": text_features
                                    }

        return dct_with_representations

# %%
"""Main method to train the model."""

# !/usr/bin/python

import argparse
import sys
import gc
import time
import numpy as np
from tensorboardX import SummaryWriter
from torch.autograd import Variable
import torch
import torch.utils.data
import torchvision
from tqdm import tqdm as tqdm
from copy import deepcopy
import socket
import os
from datetime import datetime

torch.set_num_threads(3)


def parse_opt():
    """Parses the input arguments."""
    parser = argparse.ArgumentParser()
    parser.add_argument('-f', type=str, default='')
    parser.add_argument('--comment', type=str, default= 'mitstates_composeAE')
    parser.add_argument('--dataset', type=str, default = 'mitstates')
    parser.add_argument('--dataset_path', type=str, default = '/content/data/mitstates')
    parser.add_argument('--model', type=str, default='composeAE')
    parser.add_argument('--image_embed_dim', type=int, default=512)
    parser.add_argument('--use_bert', type=bool, default=True)
    parser.add_argument('--use_complete_text_query', type=bool, default=True)
    parser.add_argument('--learning_rate', type=float, default=1e-2)
    parser.add_argument('--learning_rate_decay_frequency', type=int, default=50000 )
    parser.add_argument('--batch_size', type=int, default=32)
    parser.add_argument('--weight_decay', type=float, default=5e-5)
    parser.add_argument('--category_to_train', type=str, default='all')
    parser.add_argument('--num_iters', type=int, default=10000)
    parser.add_argument('--loss', type=str, default='batch_based_classification')
    parser.add_argument('--loader_num_workers', type=int, default=4)
    parser.add_argument('--log_dir', type=str, default='/content/logs/mitstates')
    parser.add_argument('--test_only', type=bool, default=False)
    parser.add_argument('--model_checkpoint', type=str, default='')

    args = parser.parse_args()
    return args


def load_dataset(opt):
    """Loads the input datasets."""
    print(opt.dataset)
    print('Reading dataset ', opt.dataset)
    if opt.dataset == 'fashion200k':
        trainset = Fashion200k(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = Fashion200k(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'mitstates':
        trainset = MITStates(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = MITStates(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'fashionIQ':
        trainset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='val',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    else:
        print('Invalid dataset', opt.dataset)
        sys.exit()

    print('trainset size:', len(trainset))
    print('testset size:', len(testset))
    return trainset, testset


def create_model_and_optimizer(opt, texts):
    """Builds the model and related optimizer."""
    print("Creating model and optimizer for", opt.model)
    text_embed_dim = 512 if not opt.use_bert else 768

    if opt.model == 'tirg':
        model = TIRG(texts,
                                                 image_embed_dim=opt.image_embed_dim,
                                                 text_embed_dim=text_embed_dim,
                                                 use_bert=opt.use_bert,
                                                 name= opt.model)
    elif opt.model == 'composeAE':
        model = ComposeAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    elif opt.model == 'RealSpaceConcatAE':
        model = RealSpaceConcatAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    model = model.cuda()

    # create optimizer
    params = [{
        'params': [p for p in model.img_model.fc.parameters()],
        'lr': opt.learning_rate
    }, {
        'params': [p for p in model.img_model.parameters()],
        'lr': 0.1 * opt.learning_rate
    }, {'params': [p for p in model.parameters()]}]

    for _, p1 in enumerate(params):  # remove duplicated params
        for _, p2 in enumerate(params):
            if p1 is not p2:
                for p11 in p1['params']:
                    for j, p22 in enumerate(p2['params']):
                        if p11 is p22:
                            p2['params'][j] = torch.tensor(0.0, requires_grad=True)

    optimizer = torch.optim.SGD(params,
                                lr=opt.learning_rate,
                                momentum=0.9,
                                weight_decay=opt.weight_decay)

    return model, optimizer


def train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer):
    """Function for train loop"""
    print('Begin training')
    print(len(trainset.test_queries), len(testset.test_queries))
    torch.backends.cudnn.benchmark = True
    losses_tracking = {}
    it = 0
    epoch = -1
    tic = time.time()
    l2_loss = torch.nn.MSELoss().cuda()

    while it < opt.num_iters:
        epoch += 1

        # show/log stats
        print('It', it, 'epoch', epoch, 'Elapsed time', round(time.time() - tic,
                                                              4), opt.comment)
        tic = time.time()
        for loss_name in losses_tracking:
            avg_loss = np.mean(losses_tracking[loss_name][-len(trainloader):])
            print('    Loss', loss_name, round(avg_loss, 4))
            logger.add_scalar(loss_name, avg_loss, it)
        logger.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], it)

        if epoch % 1 == 0:
            gc.collect()

        # test
        if epoch % 3 == 1:
            tests = []
            for name, dataset in [('train', trainset), ('test', testset)]:
                if opt.dataset == 'fashionIQ':
                    t = fiq_test(opt, model, dataset)
                else:
                    t = test(opt, model, dataset)
                tests += [(name + ' ' + metric_name, metric_value)
                          for metric_name, metric_value in t]
            for metric_name, metric_value in tests:
                logger.add_scalar(metric_name, metric_value, it)
                print('    ', metric_name, round(metric_value, 4))

        # save checkpoint
        torch.save({
            'it': it,
            'opt': opt,
            'model_state_dict': model.state_dict(),
        },
            logger.file_writer.get_logdir() + '/latest_checkpoint.pth')

        # run training for 1 epoch
        model.train()
        trainloader = trainset.get_loader(
            batch_size=opt.batch_size,
            shuffle=True,
            drop_last=True,
            num_workers=opt.loader_num_workers)

        def training_1_iter(data):
            assert type(data) is list
            img1 = np.stack([d['source_img_data'] for d in data])
            img1 = torch.from_numpy(img1).float()
            img1 = torch.autograd.Variable(img1).cuda()

            img2 = np.stack([d['target_img_data'] for d in data])
            img2 = torch.from_numpy(img2).float()
            img2 = torch.autograd.Variable(img2).cuda()

            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    supp_text = [str(d['noun']) for d in data]
                    mods = [str(d['mod']['str']) for d in data]
                    # text_query here means complete_text_query
                    text_query = [adj + " " + noun for adj, noun in zip(mods, supp_text)]
                else:
                    text_query = [str(d['target_caption']) for d in data]
            else:
                text_query = [str(d['mod']['str']) for d in data]
            # compute loss
            if opt.loss not in ['soft_triplet', 'batch_based_classification']:
                print('Invalid loss function', opt.loss)
                sys.exit()

            losses = []
            if_soft_triplet = True if opt.loss == 'soft_triplet' else False
            loss_value, dct_with_representations = model.compute_loss(img1,
                                                                      text_query,
                                                                      img2,
                                                                      soft_triplet_loss=if_soft_triplet)

            loss_name = opt.loss
            losses += [(loss_name, loss_weights[0], loss_value.cuda())]

            if opt.model == 'composeAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]
                losses += [("rot_sym_loss", loss_weights[3], dct_with_representations["rot_sym_loss"].cuda())]
            elif opt.model == 'RealSpaceConcatAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]

            total_loss = sum([
                loss_weight * loss_value
                for loss_name, loss_weight, loss_value in losses
            ])
            assert not torch.isnan(total_loss)
            losses += [('total training loss', None, total_loss.item())]

            # track losses
            for loss_name, loss_weight, loss_value in losses:
                if loss_name not in losses_tracking:
                    losses_tracking[loss_name] = []
                losses_tracking[loss_name].append(float(loss_value))

            torch.autograd.set_detect_anomaly(True)

            # gradient descendt
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        for data in tqdm(trainloader, desc='Training for epoch ' + str(epoch)):
            it += 1
            training_1_iter(data)

            # decay learning rate
            if it >= opt.learning_rate_decay_frequency and it % opt.learning_rate_decay_frequency == 0:
                for g in optimizer.param_groups:
                    g['lr'] *= 0.1

    print('Finished training')


def main():
    opt = parse_opt()
    print('Arguments:')
    for k in opt.__dict__.keys():
        print('    ', k, ':', str(opt.__dict__[k]))

    current_time = datetime.now().strftime('%b%d_%H-%M-%S')
    loss_weights = [1.0, 0.1, 0.1, 0.01]
    comment = opt.comment if opt.comment is not None else ''
    logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + comment)
    # logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + opt.comment)

    logger = SummaryWriter(logdir)
    print('Log files saved to', logger.file_writer.get_logdir())
    for k in opt.__dict__.keys():
        logger.add_text(k, str(opt.__dict__[k]))

    trainset, testset = load_dataset(opt)
    model, optimizer = create_model_and_optimizer(opt, [t for t in trainset.get_all_texts()])
    if opt.test_only:
        print('Doing test only')
        checkpoint = torch.load(opt.model_checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'])
        it = checkpoint['it']
        model.eval()
        tests = []
        it = 0
        for name, dataset in [('train', trainset), ('test', testset)]:
            if opt.dataset == 'fashionIQ':
                t = fiq_test(opt, model, dataset)
            else:
                t = test(opt, model, dataset)
            tests += [(name + ' ' + metric_name, metric_value) for metric_name, metric_value in t]
        for metric_name, metric_value in tests:
            logger.add_scalar(metric_name, metric_value, it)
            print('    ', metric_name, round(metric_value, 4))

        return 0
    train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
    logger.close()


if __name__ == '__main__':
    main()
# Out:
# Arguments:
#      f : /root/.local/share/jupyter/runtime/kernel-011ef976-1637-4fd1-9b07-537fe0b6ebfe.json
#      comment : mitstates_composeAE
#      dataset : mitstates
#      dataset_path : /content/data/mitstates
#      model : composeAE
#      image_embed_dim : 512
#      use_bert : True
#      use_complete_text_query : True
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 50000
#      batch_size : 32
#      weight_decay : 5e-05
#      category_to_train : all
#      num_iters : 10000
#      loss : batch_based_classification
#      loader_num_workers : 4
#      log_dir : /content/logs/mitstates
#      test_only : False
#      model_checkpoint :
# Log files saved to /content/logs/mitstates/Dec13_13-23-01_92976d119f34mitstates_composeAE
# mitstates
# Reading dataset  mitstates
# 82732 test queries
# trainset size: 43207
# testset size: 10546
# Creating model and optimizer for composeAE
# Begin training
# 0 82732
# It 0 epoch 0 Elapsed time 0.0001 mitstates_composeAE
# Training for epoch 0: 100%|██████████| 1350/1350 [06:46<00:00,  3.32it/s]
# It 1350 epoch 1 Elapsed time 407.9429 mitstates_composeAE
#     Loss batch_based_classification 2.063
#     Loss L2_loss 0.4951
#     Loss L2_loss_text 0.138
#     Loss rot_sym_loss 3.6443
#     Loss total training loss 2.1628
# 100%|██████████| 82732/82732 [06:43<00:00, 205.02it/s]
# 100%|██████████| 10546/10546 [00:35<00:00, 298.61it/s]
#      train recall_top1_correct_composition 0.0902
#      train recall_top1_correct_adj 0.1914
#      train recall_top1_correct_noun 0.2947
#      train recall_top5_correct_composition 0.2461
#      train recall_top5_correct_adj 0.4615
#      train recall_top5_correct_noun 0.6016
#      train recall_top10_correct_composition 0.3686
#      train recall_top10_correct_adj 0.628
#      train recall_top10_correct_noun 0.7494
#      train recall_top50_correct_composition 0.7308
#      train recall_top50_correct_adj 0.9305
#      train recall_top50_correct_noun 0.9581
#      train recall_top100_correct_composition 0.8518
#      train recall_top100_correct_adj 0.976
#      train recall_top100_correct_noun 0.9868
#      test recall_top1_correct_composition 0.0638
#      test recall_top1_correct_adj 0.1228
#      test recall_top1_correct_noun 0.3668
#      test recall_top5_correct_composition 0.2092
#      test recall_top5_correct_adj 0.371
#      test recall_top5_correct_noun 0.6775
#      test recall_top10_correct_composition 0.3214
#      test recall_top10_correct_adj 0.5243
#      test recall_top10_correct_noun 0.8082
#      test recall_top50_correct_composition 0.6374
#      test recall_top50_correct_adj 0.8288
#      test recall_top50_correct_noun 0.9641
#      test recall_top100_correct_composition 0.7684
#      test recall_top100_correct_adj 0.9141
#      test recall_top100_correct_noun 0.9879
# Training for epoch 1: 100%|██████████| 1350/1350 [06:47<00:00,  3.31it/s]
# It 2700 epoch 2 Elapsed time 970.5472 mitstates_composeAE
#     Loss batch_based_classification 1.6456
#     Loss L2_loss 0.4251
#     Loss L2_loss_text 0.0769
#     Loss rot_sym_loss 3.2465
#     Loss total training loss 1.7282
# Training for epoch 2: 100%|██████████| 1350/1350 [06:49<00:00,  3.30it/s]
# It 4050 epoch 3 Elapsed time 411.2877 mitstates_composeAE
#     Loss batch_based_classification 1.4206
#     Loss L2_loss 0.3845
#     Loss L2_loss_text 0.0721
#     Loss rot_sym_loss 2.8658
#     Loss total training loss 1.4949
# Training for epoch 3: 100%|██████████| 1350/1350 [06:53<00:00,  3.26it/s]
# It 5400 epoch 4 Elapsed time 415.4315 mitstates_composeAE
#     Loss batch_based_classification 1.2684
#     Loss L2_loss 0.371
#     Loss L2_loss_text 0.0694
#     Loss rot_sym_loss 2.6203
#     Loss total training loss 1.3387
# 100%|██████████| 82732/82732 [06:49<00:00, 202.23it/s]
# 100%|██████████| 10546/10546 [00:36<00:00, 291.95it/s]
#      train recall_top1_correct_composition 0.2341
#      train recall_top1_correct_adj 0.3958
#      train recall_top1_correct_noun 0.4508
#      train recall_top5_correct_composition 0.5297
#      train recall_top5_correct_adj 0.7257
#      train recall_top5_correct_noun 0.784
#      train recall_top10_correct_composition 0.6633
#      train recall_top10_correct_adj 0.8524
#      train recall_top10_correct_noun 0.8807
#      train recall_top50_correct_composition 0.9254
#      train recall_top50_correct_adj 0.9854
#      train recall_top50_correct_noun 0.9879
#      train recall_top100_correct_composition 0.9731
#      train recall_top100_correct_adj 0.9961
#      train recall_top100_correct_noun 0.9973
#      test recall_top1_correct_composition 0.0934
#      test recall_top1_correct_adj 0.1794
#      test recall_top1_correct_noun 0.4039
#      test recall_top5_correct_composition 0.2856
#      test recall_top5_correct_adj 0.4861
#      test recall_top5_correct_noun 0.6957
#      test recall_top10_correct_composition 0.4135
#      test recall_top10_correct_adj 0.6406
#      test recall_top10_correct_noun 0.8092
#      test recall_top50_correct_composition 0.7321
#      test recall_top50_correct_adj 0.9122
#      test recall_top50_correct_noun 0.9663
#      test recall_top100_correct_composition 0.8354
#      test recall_top100_correct_adj 0.9599
#      test recall_top100_correct_noun 0.9857
# Training for epoch 4: 100%|██████████| 1350/1350 [06:55<00:00,  3.25it/s]
# It 6750 epoch 5 Elapsed time 985.304 mitstates_composeAE
#     Loss batch_based_classification 1.1373
#     Loss L2_loss 0.3632
#     Loss L2_loss_text 0.0673
#     Loss rot_sym_loss 2.445
#     Loss total training loss 1.2048
# Training for epoch 5: 100%|██████████| 1350/1350 [06:55<00:00,  3.25it/s]
# It 8100 epoch 6 Elapsed time 417.0864 mitstates_composeAE
#     Loss batch_based_classification 1.0302
#     Loss L2_loss 0.3591
#     Loss L2_loss_text 0.0662
#     Loss rot_sym_loss 2.3649
#     Loss total training loss 1.0964
# Training for epoch 6: 100%|██████████| 1350/1350 [06:54<00:00,  3.26it/s]
# It 9450 epoch 7 Elapsed time 415.9226 mitstates_composeAE
#     Loss batch_based_classification 0.9171
#     Loss L2_loss 0.3588
#     Loss L2_loss_text 0.0654
#     Loss rot_sym_loss 2.2813
#     Loss total training loss 0.9823
# 100%|██████████| 82732/82732 [06:48<00:00, 202.30it/s]
# 100%|██████████| 10546/10546 [00:35<00:00, 298.39it/s]
#      train recall_top1_correct_composition 0.3314
#      train recall_top1_correct_adj 0.5468
#      train recall_top1_correct_noun 0.5103
#      train recall_top5_correct_composition 0.6665
#      train recall_top5_correct_adj 0.8522
#      train recall_top5_correct_noun 0.8332
#      train recall_top10_correct_composition 0.8047
#      train recall_top10_correct_adj 0.9394
#      train recall_top10_correct_noun 0.9199
#      train recall_top50_correct_composition 0.9657
#      train recall_top50_correct_adj 0.9966
#      train recall_top50_correct_noun 0.9929
#      train recall_top100_correct_composition 0.9886
#      train recall_top100_correct_adj 0.9991
#      train recall_top100_correct_noun 0.9979
#      test recall_top1_correct_composition 0.1218
#      test recall_top1_correct_adj 0.2413
#      test recall_top1_correct_noun 0.3751
#      test recall_top5_correct_composition 0.3158
#      test recall_top5_correct_adj 0.5414
#      test recall_top5_correct_noun 0.6804
#      test recall_top10_correct_composition 0.4277
#      test recall_top10_correct_adj 0.6774
#      test recall_top10_correct_noun 0.7939
#      test recall_top50_correct_composition 0.7259
#      test recall_top50_correct_adj 0.9181
#      test recall_top50_correct_noun 0.961
#      test recall_top100_correct_composition 0.8184
#      test recall_top100_correct_adj 0.9646
#      test recall_top100_correct_noun 0.985
# Training for epoch 7: 100%|██████████| 1350/1350 [06:54<00:00,  3.26it/s]
# Finished training

# %%
"""Main method to train the model."""

# !/usr/bin/python

import argparse
import sys
import gc
import time
import numpy as np
from tensorboardX import SummaryWriter
from torch.autograd import Variable
import torch
import torch.utils.data
import torchvision
from tqdm import tqdm as tqdm
from copy import deepcopy
import socket
import os
from datetime import datetime

torch.set_num_threads(3)


def parse_opt():
    """Parses the input arguments."""
    parser = argparse.ArgumentParser()
    parser.add_argument('-f', type=str, default='')
    parser.add_argument('--comment', type=str, default= 'mitstates_composeAE')
    parser.add_argument('--dataset', type=str, default = 'mitstates')
    parser.add_argument('--dataset_path', type=str, default = '/content/data/mitstates')
    parser.add_argument('--model', type=str, default='composeAE')
    parser.add_argument('--image_embed_dim', type=int, default=512)
    parser.add_argument('--use_bert', type=bool, default=True)
    parser.add_argument('--use_complete_text_query', type=bool, default=True)
    parser.add_argument('--learning_rate', type=float, default=1e-2)
    parser.add_argument('--learning_rate_decay_frequency', type=int, default=50000 )
    parser.add_argument('--batch_size', type=int, default=32)
    parser.add_argument('--weight_decay', type=float, default=5e-5)
    parser.add_argument('--category_to_train', type=str, default='all')
    parser.add_argument('--num_iters', type=int, default=10000)
    parser.add_argument('--loss', type=str, default='batch_based_classification')
    parser.add_argument('--loader_num_workers', type=int, default=4)
    parser.add_argument('--log_dir', type=str, default='/content/logs/mitstates')
    parser.add_argument('--test_only', type=bool, default=True)
    parser.add_argument('--model_checkpoint', type=str, default='/content/logs/mitstates/Dec13_13-23-01_92976d119f34mitstates_composeAE/latest_checkpoint.pth')

    args = parser.parse_args()
    return args


def load_dataset(opt):
    """Loads the input datasets."""
    print(opt.dataset)
    print('Reading dataset ', opt.dataset)
    if opt.dataset == 'fashion200k':
        trainset = Fashion200k(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = Fashion200k(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'mitstates':
        trainset = MITStates(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = MITStates(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'fashionIQ':
        trainset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='val',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    else:
        print('Invalid dataset', opt.dataset)
        sys.exit()

    print('trainset size:', len(trainset))
    print('testset size:', len(testset))
    return trainset, testset


def create_model_and_optimizer(opt, texts):
    """Builds the model and related optimizer."""
    print("Creating model and optimizer for", opt.model)
    text_embed_dim = 512 if not opt.use_bert else 768

    if opt.model == 'tirg':
        model = TIRG(texts,
                                                 image_embed_dim=opt.image_embed_dim,
                                                 text_embed_dim=text_embed_dim,
                                                 use_bert=opt.use_bert,
                                                 name= opt.model)
    elif opt.model == 'composeAE':
        model = ComposeAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    elif opt.model == 'RealSpaceConcatAE':
        model = RealSpaceConcatAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    model = model.cuda()

    # create optimizer
    params = [{
        'params': [p for p in model.img_model.fc.parameters()],
        'lr': opt.learning_rate
    }, {
        'params': [p for p in model.img_model.parameters()],
        'lr': 0.1 * opt.learning_rate
    }, {'params': [p for p in model.parameters()]}]

    for _, p1 in enumerate(params):  # remove duplicated params
        for _, p2 in enumerate(params):
            if p1 is not p2:
                for p11 in p1['params']:
                    for j, p22 in enumerate(p2['params']):
                        if p11 is p22:
                            p2['params'][j] = torch.tensor(0.0, requires_grad=True)

    optimizer = torch.optim.SGD(params,
                                lr=opt.learning_rate,
                                momentum=0.9,
                                weight_decay=opt.weight_decay)

    return model, optimizer


def train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer):
    """Function for train loop"""
    print('Begin training')
    print(len(trainset.test_queries), len(testset.test_queries))
    torch.backends.cudnn.benchmark = True
    losses_tracking = {}
    it = 0
    epoch = -1
    tic = time.time()
    l2_loss = torch.nn.MSELoss().cuda()

    while it < opt.num_iters:
        epoch += 1

        # show/log stats
        print('It', it, 'epoch', epoch, 'Elapsed time', round(time.time() - tic,
                                                              4), opt.comment)
        tic = time.time()
        for loss_name in losses_tracking:
            avg_loss = np.mean(losses_tracking[loss_name][-len(trainloader):])
            print('    Loss', loss_name, round(avg_loss, 4))
            logger.add_scalar(loss_name, avg_loss, it)
        logger.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], it)

        if epoch % 1 == 0:
            gc.collect()

        # test
        if epoch % 3 == 1:
            tests = []
            for name, dataset in [('train', trainset), ('test', testset)]:
                if opt.dataset == 'fashionIQ':
                    t = fiq_test(opt, model, dataset)
                else:
                    t = test(opt, model, dataset)
                tests += [(name + ' ' + metric_name, metric_value)
                          for metric_name, metric_value in t]
            for metric_name, metric_value in tests:
                logger.add_scalar(metric_name, metric_value, it)
                print('    ', metric_name, round(metric_value, 4))

        # save checkpoint
        torch.save({
            'it': it,
            'opt': opt,
            'model_state_dict': model.state_dict(),
        },
            logger.file_writer.get_logdir() + '/latest_checkpoint.pth')

        # run training for 1 epoch
        model.train()
        trainloader = trainset.get_loader(
            batch_size=opt.batch_size,
            shuffle=True,
            drop_last=True,
            num_workers=opt.loader_num_workers)

        def training_1_iter(data):
            assert type(data) is list
            img1 = np.stack([d['source_img_data'] for d in data])
            img1 = torch.from_numpy(img1).float()
            img1 = torch.autograd.Variable(img1).cuda()

            img2 = np.stack([d['target_img_data'] for d in data])
            img2 = torch.from_numpy(img2).float()
            img2 = torch.autograd.Variable(img2).cuda()

            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    supp_text = [str(d['noun']) for d in data]
                    mods = [str(d['mod']['str']) for d in data]
                    # text_query here means complete_text_query
                    text_query = [adj + " " + noun for adj, noun in zip(mods, supp_text)]
                else:
                    text_query = [str(d['target_caption']) for d in data]
            else:
                text_query = [str(d['mod']['str']) for d in data]
            # compute loss
            if opt.loss not in ['soft_triplet', 'batch_based_classification']:
                print('Invalid loss function', opt.loss)
                sys.exit()

            losses = []
            if_soft_triplet = True if opt.loss == 'soft_triplet' else False
            loss_value, dct_with_representations = model.compute_loss(img1,
                                                                      text_query,
                                                                      img2,
                                                                      soft_triplet_loss=if_soft_triplet)

            loss_name = opt.loss
            losses += [(loss_name, loss_weights[0], loss_value.cuda())]

            if opt.model == 'composeAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]
                losses += [("rot_sym_loss", loss_weights[3], dct_with_representations["rot_sym_loss"].cuda())]
            elif opt.model == 'RealSpaceConcatAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]

            total_loss = sum([
                loss_weight * loss_value
                for loss_name, loss_weight, loss_value in losses
            ])
            assert not torch.isnan(total_loss)
            losses += [('total training loss', None, total_loss.item())]

            # track losses
            for loss_name, loss_weight, loss_value in losses:
                if loss_name not in losses_tracking:
                    losses_tracking[loss_name] = []
                losses_tracking[loss_name].append(float(loss_value))

            torch.autograd.set_detect_anomaly(True)

            # gradient descendt
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        for data in tqdm(trainloader, desc='Training for epoch ' + str(epoch)):
            it += 1
            training_1_iter(data)

            # decay learning rate
            if it >= opt.learning_rate_decay_frequency and it % opt.learning_rate_decay_frequency == 0:
                for g in optimizer.param_groups:
                    g['lr'] *= 0.1

    print('Finished training')


def main():
    opt = parse_opt()
    print('Arguments:')
    for k in opt.__dict__.keys():
        print('    ', k, ':', str(opt.__dict__[k]))

    current_time = datetime.now().strftime('%b%d_%H-%M-%S')
    loss_weights = [1.0, 0.1, 0.1, 0.01]
    comment = opt.comment if opt.comment is not None else ''
    logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + comment)
    # logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + opt.comment)

    logger = SummaryWriter(logdir)
    print('Log files saved to', logger.file_writer.get_logdir())
    for k in opt.__dict__.keys():
        logger.add_text(k, str(opt.__dict__[k]))

    trainset, testset = load_dataset(opt)
    model, optimizer = create_model_and_optimizer(opt, [t for t in trainset.get_all_texts()])
    if opt.test_only:
        print('Doing test only')
        checkpoint = torch.load(opt.model_checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'])
        it = checkpoint['it']
        model.eval()
        tests = []
        it = 0
        for name, dataset in [('train', trainset), ('test', testset)]:
            if opt.dataset == 'fashionIQ':
                t = fiq_test(opt, model, dataset)
            else:
                t = test(opt, model, dataset)
            tests += [(name + ' ' + metric_name, metric_value) for metric_name, metric_value in t]
        for metric_name, metric_value in tests:
            logger.add_scalar(metric_name, metric_value, it)
            print('    ', metric_name, round(metric_value, 4))

        return 0
    train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
    logger.close()


if __name__ == '__main__':
    main()
# Out:
# Arguments:
#      f : /root/.local/share/jupyter/runtime/kernel-011ef976-1637-4fd1-9b07-537fe0b6ebfe.json
#      comment : mitstates_composeAE
#      dataset : mitstates
#      dataset_path : /content/data/mitstates
#      model : composeAE
#      image_embed_dim : 512
#      use_bert : True
#      use_complete_text_query : True
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 50000
#      batch_size : 32
#      weight_decay : 5e-05
#      category_to_train : all
#      num_iters : 10000
#      loss : batch_based_classification
#      loader_num_workers : 4
#      log_dir : /content/logs/mitstates
#      test_only : True
#      model_checkpoint : /content/logs/mitstates/Dec13_13-23-01_92976d119f34mitstates_composeAE/latest_checkpoint.pth
# Log files saved to /content/logs/mitstates/Dec13_18-40-56_92976d119f34mitstates_composeAE
# mitstates
# Reading dataset  mitstates
# 82732 test queries
# trainset size: 43207
# testset size: 10546
# Creating model and optimizer for composeAE
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Doing test only
# <ipython-input-27-7e92ad5471a0>:342: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(opt.model_checkpoint)
# 100%|██████████| 82732/82732 [06:48<00:00, 202.29it/s]
# 100%|██████████| 10546/10546 [00:35<00:00, 300.97it/s]
#      train recall_top1_correct_composition 0.3111
#      train recall_top1_correct_adj 0.5357
#      train recall_top1_correct_noun 0.5015
#      train recall_top5_correct_composition 0.6518
#      train recall_top5_correct_adj 0.85
#      train recall_top5_correct_noun 0.8231
#      train recall_top10_correct_composition 0.7817
#      train recall_top10_correct_adj 0.9275
#      train recall_top10_correct_noun 0.9156
#      train recall_top50_correct_composition 0.9666
#      train recall_top50_correct_adj 0.9959
#      train recall_top50_correct_noun 0.9931
#      train recall_top100_correct_composition 0.9894
#      train recall_top100_correct_adj 0.9993
#      train recall_top100_correct_noun 0.9985
#      test recall_top1_correct_composition 0.1218
#      test recall_top1_correct_adj 0.2413
#      test recall_top1_correct_noun 0.3751
#      test recall_top5_correct_composition 0.3158
#      test recall_top5_correct_adj 0.5414
#      test recall_top5_correct_noun 0.6804
#      test recall_top10_correct_composition 0.4277
#      test recall_top10_correct_adj 0.6774
#      test recall_top10_correct_noun 0.7939
#      test recall_top50_correct_composition 0.7259
#      test recall_top50_correct_adj 0.9181
#      test recall_top50_correct_noun 0.961
#      test recall_top100_correct_composition 0.8184
#      test recall_top100_correct_adj 0.9646
#      test recall_top100_correct_noun 0.985

# %%
"""Main method to train the model."""

# !/usr/bin/python

import argparse
import sys
import gc
import time
import numpy as np
from tensorboardX import SummaryWriter
from torch.autograd import Variable
import torch
import torch.utils.data
import torchvision
from tqdm import tqdm as tqdm
from copy import deepcopy
import socket
import os
from datetime import datetime

torch.set_num_threads(3)


def parse_opt():
    """Parses the input arguments."""
    parser = argparse.ArgumentParser()
    parser.add_argument('-f', type=str, default='')
    parser.add_argument('--comment', type=str, default= 'mitstates_tirg_original')
    parser.add_argument('--dataset', type=str, default = 'mitstates')
    parser.add_argument('--dataset_path', type=str, default = '/content/data/mitstates')
    parser.add_argument('--model', type=str, default='tirg')
    parser.add_argument('--image_embed_dim', type=int, default=512)
    parser.add_argument('--use_bert', type=bool, default=False)
    parser.add_argument('--use_complete_text_query', type=bool, default=False)
    parser.add_argument('--learning_rate', type=float, default=1e-2)
    parser.add_argument('--learning_rate_decay_frequency', type=int, default=50000)
    parser.add_argument('--batch_size', type=int, default=32)
    parser.add_argument('--weight_decay', type=float, default=5e-5)
    parser.add_argument('--category_to_train', type=str, default='all')
    parser.add_argument('--num_iters', type=int, default=10000)
    parser.add_argument('--loss', type=str, default='soft_triplet')
    parser.add_argument('--loader_num_workers', type=int, default=4)
    parser.add_argument('--log_dir', type=str, default='/content/logs/mitstates')
    parser.add_argument('--test_only', type=bool, default=False)
    parser.add_argument('--model_checkpoint', type=str, default='')

    args = parser.parse_args()
    return args


def load_dataset(opt):
    """Loads the input datasets."""
    print(opt.dataset)
    print('Reading dataset ', opt.dataset)
    if opt.dataset == 'fashion200k':
        trainset = Fashion200k(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = Fashion200k(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'mitstates':
        trainset = MITStates(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = MITStates(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'fashionIQ':
        trainset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='val',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    else:
        print('Invalid dataset', opt.dataset)
        sys.exit()

    print('trainset size:', len(trainset))
    print('testset size:', len(testset))
    return trainset, testset


def create_model_and_optimizer(opt, texts):
    """Builds the model and related optimizer."""
    print("Creating model and optimizer for", opt.model)
    text_embed_dim = 512 if not opt.use_bert else 768

    if opt.model == 'tirg':
        model = TIRG(texts,
                                                 image_embed_dim=opt.image_embed_dim,
                                                 text_embed_dim=text_embed_dim,
                                                 use_bert=opt.use_bert,
                                                 name= opt.model)
    elif opt.model == 'composeAE':
        model = ComposeAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    elif opt.model == 'RealSpaceConcatAE':
        model = RealSpaceConcatAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    model = model.cuda()

    # create optimizer
    params = [{
        'params': [p for p in model.img_model.fc.parameters()],
        'lr': opt.learning_rate
    }, {
        'params': [p for p in model.img_model.parameters()],
        'lr': 0.1 * opt.learning_rate
    }, {'params': [p for p in model.parameters()]}]

    for _, p1 in enumerate(params):  # remove duplicated params
        for _, p2 in enumerate(params):
            if p1 is not p2:
                for p11 in p1['params']:
                    for j, p22 in enumerate(p2['params']):
                        if p11 is p22:
                            p2['params'][j] = torch.tensor(0.0, requires_grad=True)

    optimizer = torch.optim.SGD(params,
                                lr=opt.learning_rate,
                                momentum=0.9,
                                weight_decay=opt.weight_decay)

    return model, optimizer


def train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer):
    """Function for train loop"""
    print('Begin training')
    print(len(trainset.test_queries), len(testset.test_queries))
    torch.backends.cudnn.benchmark = True
    losses_tracking = {}
    it = 0
    epoch = -1
    tic = time.time()
    l2_loss = torch.nn.MSELoss().cuda()

    while it < opt.num_iters:
        epoch += 1

        # show/log stats
        print('It', it, 'epoch', epoch, 'Elapsed time', round(time.time() - tic,
                                                              4), opt.comment)
        tic = time.time()
        for loss_name in losses_tracking:
            avg_loss = np.mean(losses_tracking[loss_name][-len(trainloader):])
            print('    Loss', loss_name, round(avg_loss, 4))
            logger.add_scalar(loss_name, avg_loss, it)
        logger.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], it)

        if epoch % 1 == 0:
            gc.collect()

        # test
        if epoch % 3 == 1:
            tests = []
            for name, dataset in [('train', trainset), ('test', testset)]:
                if opt.dataset == 'fashionIQ':
                    t = fiq_test(opt, model, dataset)
                else:
                    t = test(opt, model, dataset)
                tests += [(name + ' ' + metric_name, metric_value)
                          for metric_name, metric_value in t]
            for metric_name, metric_value in tests:
                logger.add_scalar(metric_name, metric_value, it)
                print('    ', metric_name, round(metric_value, 4))

        # save checkpoint
        torch.save({
            'it': it,
            'opt': opt,
            'model_state_dict': model.state_dict(),
        },
            logger.file_writer.get_logdir() + '/latest_checkpoint.pth')

        # run training for 1 epoch
        model.train()
        trainloader = trainset.get_loader(
            batch_size=opt.batch_size,
            shuffle=True,
            drop_last=True,
            num_workers=opt.loader_num_workers)

        def training_1_iter(data):
            assert type(data) is list
            img1 = np.stack([d['source_img_data'] for d in data])
            img1 = torch.from_numpy(img1).float()
            img1 = torch.autograd.Variable(img1).cuda()

            img2 = np.stack([d['target_img_data'] for d in data])
            img2 = torch.from_numpy(img2).float()
            img2 = torch.autograd.Variable(img2).cuda()

            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    supp_text = [str(d['noun']) for d in data]
                    mods = [str(d['mod']['str']) for d in data]
                    # text_query here means complete_text_query
                    text_query = [adj + " " + noun for adj, noun in zip(mods, supp_text)]
                else:
                    text_query = [str(d['target_caption']) for d in data]
            else:
                text_query = [str(d['mod']['str']) for d in data]
            # compute loss
            if opt.loss not in ['soft_triplet', 'batch_based_classification']:
                print('Invalid loss function', opt.loss)
                sys.exit()

            losses = []
            if_soft_triplet = True if opt.loss == 'soft_triplet' else False
            loss_value, dct_with_representations = model.compute_loss(img1,
                                                                      text_query,
                                                                      img2,
                                                                      soft_triplet_loss=if_soft_triplet)

            loss_name = opt.loss
            losses += [(loss_name, loss_weights[0], loss_value.cuda())]

            if opt.model == 'composeAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]
                losses += [("rot_sym_loss", loss_weights[3], dct_with_representations["rot_sym_loss"].cuda())]
            elif opt.model == 'RealSpaceConcatAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]

            total_loss = sum([
                loss_weight * loss_value
                for loss_name, loss_weight, loss_value in losses
            ])
            assert not torch.isnan(total_loss)
            losses += [('total training loss', None, total_loss.item())]

            # track losses
            for loss_name, loss_weight, loss_value in losses:
                if loss_name not in losses_tracking:
                    losses_tracking[loss_name] = []
                losses_tracking[loss_name].append(float(loss_value))

            torch.autograd.set_detect_anomaly(True)

            # gradient descendt
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        for data in tqdm(trainloader, desc='Training for epoch ' + str(epoch)):
            it += 1
            training_1_iter(data)

            # decay learning rate
            if it >= opt.learning_rate_decay_frequency and it % opt.learning_rate_decay_frequency == 0:
                for g in optimizer.param_groups:
                    g['lr'] *= 0.1

    print('Finished training')


def main():
    opt = parse_opt()
    print('Arguments:')
    for k in opt.__dict__.keys():
        print('    ', k, ':', str(opt.__dict__[k]))

    current_time = datetime.now().strftime('%b%d_%H-%M-%S')
    loss_weights = [1.0, 0.1, 0.1, 0.01]
    comment = opt.comment if opt.comment is not None else ''
    logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + comment)
    # logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + opt.comment)

    logger = SummaryWriter(logdir)
    print('Log files saved to', logger.file_writer.get_logdir())
    for k in opt.__dict__.keys():
        logger.add_text(k, str(opt.__dict__[k]))

    trainset, testset = load_dataset(opt)
    model, optimizer = create_model_and_optimizer(opt, [t for t in trainset.get_all_texts()])
    if opt.test_only:
        print('Doing test only')
        checkpoint = torch.load(opt.model_checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'])
        it = checkpoint['it']
        model.eval()
        tests = []
        it = 0
        for name, dataset in [('train', trainset), ('test', testset)]:
            if opt.dataset == 'fashionIQ':
                t = fiq_test(opt, model, dataset)
            else:
                t = test(opt, model, dataset)
            tests += [(name + ' ' + metric_name, metric_value) for metric_name, metric_value in t]
        for metric_name, metric_value in tests:
            logger.add_scalar(metric_name, metric_value, it)
            print('    ', metric_name, round(metric_value, 4))

        return 0
    train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
    logger.close()


if __name__ == '__main__':
    main()
# Out:
# Arguments:
#      f : /root/.local/share/jupyter/runtime/kernel-011ef976-1637-4fd1-9b07-537fe0b6ebfe.json
#      comment : mitstates_tirg_original
#      dataset : mitstates
#      dataset_path : /content/data/mitstates
#      model : tirg
#      image_embed_dim : 512
#      use_bert : False
#      use_complete_text_query : False
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 50000
#      batch_size : 32
#      weight_decay : 5e-05
#      category_to_train : all
#      num_iters : 10000
#      loss : soft_triplet
#      loader_num_workers : 4
#      log_dir : /content/logs/mitstates
#      test_only : False
#      model_checkpoint :
# Log files saved to /content/logs/mitstates/Dec13_15-03-02_92976d119f34mitstates_tirg_original
# mitstates
# Reading dataset  mitstates
# 82732 test queries
# trainset size: 43207
# testset size: 10546
# Creating model and optimizer for tirg
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Begin training
# 0 82732
# It 0 epoch 0 Elapsed time 0.0001 mitstates_tirg_original
# Training for epoch 0: 100%|██████████| 1350/1350 [05:40<00:00,  3.96it/s]
# It 1350 epoch 1 Elapsed time 341.154 mitstates_tirg_original
#     Loss soft_triplet 0.2536
#     Loss total training loss 0.2536
# 100%|██████████| 82732/82732 [06:27<00:00, 213.62it/s]
# 100%|██████████| 10546/10546 [00:35<00:00, 293.86it/s]
#      train recall_top1_correct_composition 0.0864
#      train recall_top1_correct_adj 0.2177
#      train recall_top1_correct_noun 0.3431
#      train recall_top5_correct_composition 0.2152
#      train recall_top5_correct_adj 0.5169
#      train recall_top5_correct_noun 0.5802
#      train recall_top10_correct_composition 0.3156
#      train recall_top10_correct_adj 0.6757
#      train recall_top10_correct_noun 0.6961
#      train recall_top50_correct_composition 0.6222
#      train recall_top50_correct_adj 0.9383
#      train recall_top50_correct_noun 0.914
#      train recall_top100_correct_composition 0.7535
#      train recall_top100_correct_adj 0.9749
#      train recall_top100_correct_noun 0.9593
#      test recall_top1_correct_composition 0.077
#      test recall_top1_correct_adj 0.164
#      test recall_top1_correct_noun 0.3774
#      test recall_top5_correct_composition 0.2474
#      test recall_top5_correct_adj 0.4489
#      test recall_top5_correct_noun 0.691
#      test recall_top10_correct_composition 0.3645
#      test recall_top10_correct_adj 0.6025
#      test recall_top10_correct_noun 0.8017
#      test recall_top50_correct_composition 0.6739
#      test recall_top50_correct_adj 0.8754
#      test recall_top50_correct_noun 0.9522
#      test recall_top100_correct_composition 0.7823
#      test recall_top100_correct_adj 0.9321
#      test recall_top100_correct_noun 0.9796
# Training for epoch 1: 100%|██████████| 1350/1350 [05:39<00:00,  3.97it/s]
# It 2700 epoch 2 Elapsed time 884.3662 mitstates_tirg_original
#     Loss soft_triplet 0.1696
#     Loss total training loss 0.1696
# Training for epoch 2: 100%|██████████| 1350/1350 [05:35<00:00,  4.02it/s]
# It 4050 epoch 3 Elapsed time 336.5108 mitstates_tirg_original
#     Loss soft_triplet 0.1451
#     Loss total training loss 0.1451
# Training for epoch 3: 100%|██████████| 1350/1350 [05:35<00:00,  4.03it/s]
# It 5400 epoch 4 Elapsed time 335.6388 mitstates_tirg_original
#     Loss soft_triplet 0.1348
#     Loss total training loss 0.1348
# 100%|██████████| 82732/82732 [06:22<00:00, 216.56it/s]
# 100%|██████████| 10546/10546 [00:34<00:00, 305.55it/s]
#      train recall_top1_correct_composition 0.12
#      train recall_top1_correct_adj 0.2991
#      train recall_top1_correct_noun 0.3134
#      train recall_top5_correct_composition 0.3036
#      train recall_top5_correct_adj 0.6757
#      train recall_top5_correct_noun 0.5823
#      train recall_top10_correct_composition 0.4261
#      train recall_top10_correct_adj 0.823
#      train recall_top10_correct_noun 0.7124
#      train recall_top50_correct_composition 0.7384
#      train recall_top50_correct_adj 0.9834
#      train recall_top50_correct_noun 0.9252
#      train recall_top100_correct_composition 0.8457
#      train recall_top100_correct_adj 0.9951
#      train recall_top100_correct_noun 0.9678
#      test recall_top1_correct_composition 0.1024
#      test recall_top1_correct_adj 0.2421
#      test recall_top1_correct_noun 0.3351
#      test recall_top5_correct_composition 0.295
#      test recall_top5_correct_adj 0.5608
#      test recall_top5_correct_noun 0.6318
#      test recall_top10_correct_composition 0.4125
#      test recall_top10_correct_adj 0.6969
#      test recall_top10_correct_noun 0.7531
#      test recall_top50_correct_composition 0.6918
#      test recall_top50_correct_adj 0.9082
#      test recall_top50_correct_noun 0.9314
#      test recall_top100_correct_composition 0.7921
#      test recall_top100_correct_adj 0.9515
#      test recall_top100_correct_noun 0.9685
# Training for epoch 4: 100%|██████████| 1350/1350 [05:36<00:00,  4.01it/s]
# It 6750 epoch 5 Elapsed time 873.4257 mitstates_tirg_original
#     Loss soft_triplet 0.122
#     Loss total training loss 0.122
# Training for epoch 5: 100%|██████████| 1350/1350 [05:34<00:00,  4.03it/s]
# It 8100 epoch 6 Elapsed time 335.3118 mitstates_tirg_original
#     Loss soft_triplet 0.1136
#     Loss total training loss 0.1136
# Training for epoch 6: 100%|██████████| 1350/1350 [05:35<00:00,  4.02it/s]
# It 9450 epoch 7 Elapsed time 336.1557 mitstates_tirg_original
#     Loss soft_triplet 0.1061
#     Loss total training loss 0.1061
# 100%|██████████| 82732/82732 [06:23<00:00, 215.76it/s]
# 100%|██████████| 10546/10546 [00:34<00:00, 302.83it/s]
#      train recall_top1_correct_composition 0.1408
#      train recall_top1_correct_adj 0.3796
#      train recall_top1_correct_noun 0.3311
#      train recall_top5_correct_composition 0.356
#      train recall_top5_correct_adj 0.7324
#      train recall_top5_correct_noun 0.6062
#      train recall_top10_correct_composition 0.4877
#      train recall_top10_correct_adj 0.869
#      train recall_top10_correct_noun 0.7355
#      train recall_top50_correct_composition 0.7881
#      train recall_top50_correct_adj 0.9903
#      train recall_top50_correct_noun 0.9368
#      train recall_top100_correct_composition 0.8862
#      train recall_top100_correct_adj 0.9966
#      train recall_top100_correct_noun 0.972
#      test recall_top1_correct_composition 0.1066
#      test recall_top1_correct_adj 0.2502
#      test recall_top1_correct_noun 0.3301
#      test recall_top5_correct_composition 0.2933
#      test recall_top5_correct_adj 0.566
#      test recall_top5_correct_noun 0.6208
#      test recall_top10_correct_composition 0.4081
#      test recall_top10_correct_adj 0.7007
#      test recall_top10_correct_noun 0.7423
#      test recall_top50_correct_composition 0.7048
#      test recall_top50_correct_adj 0.9189
#      test recall_top50_correct_noun 0.9281
#      test recall_top100_correct_composition 0.8044
#      test recall_top100_correct_adj 0.9569
#      test recall_top100_correct_noun 0.9694
# Training for epoch 7: 100%|██████████| 1350/1350 [05:36<00:00,  4.01it/s]
# Finished training

# %%
"""Main method to train the model."""

# !/usr/bin/python

import argparse
import sys
import gc
import time
import numpy as np
from tensorboardX import SummaryWriter
from torch.autograd import Variable
import torch
import torch.utils.data
import torchvision
from tqdm import tqdm as tqdm
from copy import deepcopy
import socket
import os
from datetime import datetime

torch.set_num_threads(3)


def parse_opt():
    """Parses the input arguments."""
    parser = argparse.ArgumentParser()
    parser.add_argument('-f', type=str, default='')
    parser.add_argument('--comment', type=str, default= 'mitstates_tirg_original')
    parser.add_argument('--dataset', type=str, default = 'mitstates')
    parser.add_argument('--dataset_path', type=str, default = '/content/data/mitstates')
    parser.add_argument('--model', type=str, default='tirg')
    parser.add_argument('--image_embed_dim', type=int, default=512)
    parser.add_argument('--use_bert', type=bool, default=False)
    parser.add_argument('--use_complete_text_query', type=bool, default=False)
    parser.add_argument('--learning_rate', type=float, default=1e-2)
    parser.add_argument('--learning_rate_decay_frequency', type=int, default=50000)
    parser.add_argument('--batch_size', type=int, default=32)
    parser.add_argument('--weight_decay', type=float, default=5e-5)
    parser.add_argument('--category_to_train', type=str, default='all')
    parser.add_argument('--num_iters', type=int, default=10000)
    parser.add_argument('--loss', type=str, default='soft_triplet')
    parser.add_argument('--loader_num_workers', type=int, default=4)
    parser.add_argument('--log_dir', type=str, default='/content/logs/mitstates')
    parser.add_argument('--test_only', type=bool, default=True)
    parser.add_argument('--model_checkpoint', type=str, default='/content/logs/mitstates/Dec13_15-03-02_92976d119f34mitstates_tirg_original/latest_checkpoint.pth')

    args = parser.parse_args()
    return args


def load_dataset(opt):
    """Loads the input datasets."""
    print(opt.dataset)
    print('Reading dataset ', opt.dataset)
    if opt.dataset == 'fashion200k':
        trainset = Fashion200k(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = Fashion200k(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'mitstates':
        trainset = MITStates(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = MITStates(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'fashionIQ':
        trainset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='val',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    else:
        print('Invalid dataset', opt.dataset)
        sys.exit()

    print('trainset size:', len(trainset))
    print('testset size:', len(testset))
    return trainset, testset


def create_model_and_optimizer(opt, texts):
    """Builds the model and related optimizer."""
    print("Creating model and optimizer for", opt.model)
    text_embed_dim = 512 if not opt.use_bert else 768

    if opt.model == 'tirg':
        model = TIRG(texts,
                                                 image_embed_dim=opt.image_embed_dim,
                                                 text_embed_dim=text_embed_dim,
                                                 use_bert=opt.use_bert,
                                                 name= opt.model)
    elif opt.model == 'composeAE':
        model = ComposeAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    elif opt.model == 'RealSpaceConcatAE':
        model = RealSpaceConcatAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    model = model.cuda()

    # create optimizer
    params = [{
        'params': [p for p in model.img_model.fc.parameters()],
        'lr': opt.learning_rate
    }, {
        'params': [p for p in model.img_model.parameters()],
        'lr': 0.1 * opt.learning_rate
    }, {'params': [p for p in model.parameters()]}]

    for _, p1 in enumerate(params):  # remove duplicated params
        for _, p2 in enumerate(params):
            if p1 is not p2:
                for p11 in p1['params']:
                    for j, p22 in enumerate(p2['params']):
                        if p11 is p22:
                            p2['params'][j] = torch.tensor(0.0, requires_grad=True)

    optimizer = torch.optim.SGD(params,
                                lr=opt.learning_rate,
                                momentum=0.9,
                                weight_decay=opt.weight_decay)

    return model, optimizer


def train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer):
    """Function for train loop"""
    print('Begin training')
    print(len(trainset.test_queries), len(testset.test_queries))
    torch.backends.cudnn.benchmark = True
    losses_tracking = {}
    it = 0
    epoch = -1
    tic = time.time()
    l2_loss = torch.nn.MSELoss().cuda()

    while it < opt.num_iters:
        epoch += 1

        # show/log stats
        print('It', it, 'epoch', epoch, 'Elapsed time', round(time.time() - tic,
                                                              4), opt.comment)
        tic = time.time()
        for loss_name in losses_tracking:
            avg_loss = np.mean(losses_tracking[loss_name][-len(trainloader):])
            print('    Loss', loss_name, round(avg_loss, 4))
            logger.add_scalar(loss_name, avg_loss, it)
        logger.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], it)

        if epoch % 1 == 0:
            gc.collect()

        # test
        if epoch % 3 == 1:
            tests = []
            for name, dataset in [('train', trainset), ('test', testset)]:
                if opt.dataset == 'fashionIQ':
                    t = fiq_test(opt, model, dataset)
                else:
                    t = test(opt, model, dataset)
                tests += [(name + ' ' + metric_name, metric_value)
                          for metric_name, metric_value in t]
            for metric_name, metric_value in tests:
                logger.add_scalar(metric_name, metric_value, it)
                print('    ', metric_name, round(metric_value, 4))

        # save checkpoint
        torch.save({
            'it': it,
            'opt': opt,
            'model_state_dict': model.state_dict(),
        },
            logger.file_writer.get_logdir() + '/latest_checkpoint.pth')

        # run training for 1 epoch
        model.train()
        trainloader = trainset.get_loader(
            batch_size=opt.batch_size,
            shuffle=True,
            drop_last=True,
            num_workers=opt.loader_num_workers)

        def training_1_iter(data):
            assert type(data) is list
            img1 = np.stack([d['source_img_data'] for d in data])
            img1 = torch.from_numpy(img1).float()
            img1 = torch.autograd.Variable(img1).cuda()

            img2 = np.stack([d['target_img_data'] for d in data])
            img2 = torch.from_numpy(img2).float()
            img2 = torch.autograd.Variable(img2).cuda()

            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    supp_text = [str(d['noun']) for d in data]
                    mods = [str(d['mod']['str']) for d in data]
                    # text_query here means complete_text_query
                    text_query = [adj + " " + noun for adj, noun in zip(mods, supp_text)]
                else:
                    text_query = [str(d['target_caption']) for d in data]
            else:
                text_query = [str(d['mod']['str']) for d in data]
            # compute loss
            if opt.loss not in ['soft_triplet', 'batch_based_classification']:
                print('Invalid loss function', opt.loss)
                sys.exit()

            losses = []
            if_soft_triplet = True if opt.loss == 'soft_triplet' else False
            loss_value, dct_with_representations = model.compute_loss(img1,
                                                                      text_query,
                                                                      img2,
                                                                      soft_triplet_loss=if_soft_triplet)

            loss_name = opt.loss
            losses += [(loss_name, loss_weights[0], loss_value.cuda())]

            if opt.model == 'composeAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]
                losses += [("rot_sym_loss", loss_weights[3], dct_with_representations["rot_sym_loss"].cuda())]
            elif opt.model == 'RealSpaceConcatAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]

            total_loss = sum([
                loss_weight * loss_value
                for loss_name, loss_weight, loss_value in losses
            ])
            assert not torch.isnan(total_loss)
            losses += [('total training loss', None, total_loss.item())]

            # track losses
            for loss_name, loss_weight, loss_value in losses:
                if loss_name not in losses_tracking:
                    losses_tracking[loss_name] = []
                losses_tracking[loss_name].append(float(loss_value))

            torch.autograd.set_detect_anomaly(True)

            # gradient descendt
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        for data in tqdm(trainloader, desc='Training for epoch ' + str(epoch)):
            it += 1
            training_1_iter(data)

            # decay learning rate
            if it >= opt.learning_rate_decay_frequency and it % opt.learning_rate_decay_frequency == 0:
                for g in optimizer.param_groups:
                    g['lr'] *= 0.1

    print('Finished training')


def main():
    opt = parse_opt()
    print('Arguments:')
    for k in opt.__dict__.keys():
        print('    ', k, ':', str(opt.__dict__[k]))

    current_time = datetime.now().strftime('%b%d_%H-%M-%S')
    loss_weights = [1.0, 0.1, 0.1, 0.01]
    comment = opt.comment if opt.comment is not None else ''
    logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + comment)
    # logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + opt.comment)

    logger = SummaryWriter(logdir)
    print('Log files saved to', logger.file_writer.get_logdir())
    for k in opt.__dict__.keys():
        logger.add_text(k, str(opt.__dict__[k]))

    trainset, testset = load_dataset(opt)
    model, optimizer = create_model_and_optimizer(opt, [t for t in trainset.get_all_texts()])
    if opt.test_only:
        print('Doing test only')
        checkpoint = torch.load(opt.model_checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'])
        it = checkpoint['it']
        model.eval()
        tests = []
        it = 0
        for name, dataset in [('train', trainset), ('test', testset)]:
            if opt.dataset == 'fashionIQ':
                t = fiq_test(opt, model, dataset)
            else:
                t = test(opt, model, dataset)
            tests += [(name + ' ' + metric_name, metric_value) for metric_name, metric_value in t]
        for metric_name, metric_value in tests:
            logger.add_scalar(metric_name, metric_value, it)
            print('    ', metric_name, round(metric_value, 4))

        return 0
    train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
    logger.close()


if __name__ == '__main__':
    main()
# Out:
# Arguments:
#      f : /root/.local/share/jupyter/runtime/kernel-011ef976-1637-4fd1-9b07-537fe0b6ebfe.json
#      comment : mitstates_tirg_original
#      dataset : mitstates
#      dataset_path : /content/data/mitstates
#      model : tirg
#      image_embed_dim : 512
#      use_bert : False
#      use_complete_text_query : False
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 50000
#      batch_size : 32
#      weight_decay : 5e-05
#      category_to_train : all
#      num_iters : 10000
#      loss : soft_triplet
#      loader_num_workers : 4
#      log_dir : /content/logs/mitstates
#      test_only : True
#      model_checkpoint : /content/logs/mitstates/Dec13_15-03-02_92976d119f34mitstates_tirg_original/latest_checkpoint.pth
# Log files saved to /content/logs/mitstates/Dec13_16-16-37_92976d119f34mitstates_tirg_original
# mitstates
# Reading dataset  mitstates
# 82732 test queries
# trainset size: 43207
# testset size: 10546
# Creating model and optimizer for tirg
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Doing test only
# <ipython-input-24-e473e1c23461>:342: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(opt.model_checkpoint)
# 100%|██████████| 82732/82732 [06:23<00:00, 215.48it/s]
# 100%|██████████| 10546/10546 [00:35<00:00, 299.26it/s]
#      train recall_top1_correct_composition 0.1484
#      train recall_top1_correct_adj 0.3835
#      train recall_top1_correct_noun 0.3393
#      train recall_top5_correct_composition 0.3549
#      train recall_top5_correct_adj 0.7369
#      train recall_top5_correct_noun 0.5952
#      train recall_top10_correct_composition 0.4834
#      train recall_top10_correct_adj 0.8704
#      train recall_top10_correct_noun 0.7253
#      train recall_top50_correct_composition 0.7859
#      train recall_top50_correct_adj 0.9901
#      train recall_top50_correct_noun 0.9363
#      train recall_top100_correct_composition 0.887
#      train recall_top100_correct_adj 0.9967
#      train recall_top100_correct_noun 0.9743
#      test recall_top1_correct_composition 0.1066
#      test recall_top1_correct_adj 0.2502
#      test recall_top1_correct_noun 0.3301
#      test recall_top5_correct_composition 0.2933
#      test recall_top5_correct_adj 0.566
#      test recall_top5_correct_noun 0.6208
#      test recall_top10_correct_composition 0.4081
#      test recall_top10_correct_adj 0.7007
#      test recall_top10_correct_noun 0.7423
#      test recall_top50_correct_composition 0.7048
#      test recall_top50_correct_adj 0.9189
#      test recall_top50_correct_noun 0.9281
#      test recall_top100_correct_composition 0.8044
#      test recall_top100_correct_adj 0.9569
#      test recall_top100_correct_noun 0.9694

# %%
"""Main method to train the model."""

# !/usr/bin/python

import argparse
import sys
import gc
import time
import numpy as np
from tensorboardX import SummaryWriter
from torch.autograd import Variable
import torch
import torch.utils.data
import torchvision
from tqdm import tqdm as tqdm
from copy import deepcopy
import socket
import os
from datetime import datetime

torch.set_num_threads(3)


def parse_opt():
    """Parses the input arguments."""
    parser = argparse.ArgumentParser()
    parser.add_argument('-f', type=str, default='')
    parser.add_argument('--comment', type=str, default= 'mitstates_composeAE')
    parser.add_argument('--dataset', type=str, default = 'mitstates')
    parser.add_argument('--dataset_path', type=str, default = '/content/data/mitstates')
    parser.add_argument('--model', type=str, default='composeAE')
    parser.add_argument('--image_embed_dim', type=int, default=512)
    parser.add_argument('--use_bert', type=bool, default=True)
    parser.add_argument('--use_complete_text_query', type=bool, default=True)
    parser.add_argument('--learning_rate', type=float, default=1e-3)
    parser.add_argument('--learning_rate_decay_frequency', type=int, default=50000 )
    parser.add_argument('--batch_size', type=int, default=32)
    parser.add_argument('--weight_decay', type=float, default=5e-5)
    parser.add_argument('--category_to_train', type=str, default='all')
    parser.add_argument('--num_iters', type=int, default=6750)
    parser.add_argument('--loss', type=str, default='batch_based_classification')
    parser.add_argument('--loader_num_workers', type=int, default=4)
    parser.add_argument('--log_dir', type=str, default='/content/logs/mitstates')
    parser.add_argument('--test_only', type=bool, default=False)
    parser.add_argument('--model_checkpoint', type=str, default='')

    args = parser.parse_args()
    return args


def load_dataset(opt):
    """Loads the input datasets."""
    print(opt.dataset)
    print('Reading dataset ', opt.dataset)
    if opt.dataset == 'fashion200k':
        trainset = Fashion200k(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = Fashion200k(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'mitstates':
        trainset = MITStates(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = MITStates(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'fashionIQ':
        trainset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='val',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    else:
        print('Invalid dataset', opt.dataset)
        sys.exit()

    print('trainset size:', len(trainset))
    print('testset size:', len(testset))
    return trainset, testset


def create_model_and_optimizer(opt, texts):
    """Builds the model and related optimizer."""
    print("Creating model and optimizer for", opt.model)
    text_embed_dim = 512 if not opt.use_bert else 768

    if opt.model == 'tirg':
        model = TIRG(texts,
                                                 image_embed_dim=opt.image_embed_dim,
                                                 text_embed_dim=text_embed_dim,
                                                 use_bert=opt.use_bert,
                                                 name= opt.model)
    elif opt.model == 'composeAE':
        model = ComposeAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    elif opt.model == 'RealSpaceConcatAE':
        model = RealSpaceConcatAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    model = model.cuda()

    # create optimizer
    params = [{
        'params': [p for p in model.img_model.fc.parameters()],
        'lr': opt.learning_rate
    }, {
        'params': [p for p in model.img_model.parameters()],
        'lr': 0.1 * opt.learning_rate
    }, {'params': [p for p in model.parameters()]}]

    for _, p1 in enumerate(params):  # remove duplicated params
        for _, p2 in enumerate(params):
            if p1 is not p2:
                for p11 in p1['params']:
                    for j, p22 in enumerate(p2['params']):
                        if p11 is p22:
                            p2['params'][j] = torch.tensor(0.0, requires_grad=True)

    optimizer = torch.optim.SGD(params,
                                lr=opt.learning_rate,
                                momentum=0.9,
                                weight_decay=opt.weight_decay)

    return model, optimizer


def train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer):
    """Function for train loop"""
    print('Begin training')
    print(len(trainset.test_queries), len(testset.test_queries))
    torch.backends.cudnn.benchmark = True
    losses_tracking = {}
    it = 0
    epoch = -1
    tic = time.time()
    l2_loss = torch.nn.MSELoss().cuda()

    while it < opt.num_iters:
        epoch += 1

        # show/log stats
        print('It', it, 'epoch', epoch, 'Elapsed time', round(time.time() - tic,
                                                              4), opt.comment)
        tic = time.time()
        for loss_name in losses_tracking:
            avg_loss = np.mean(losses_tracking[loss_name][-len(trainloader):])
            print('    Loss', loss_name, round(avg_loss, 4))
            logger.add_scalar(loss_name, avg_loss, it)
        logger.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], it)

        if epoch % 1 == 0:
            gc.collect()

        # test
        if epoch % 3 == 1:
            tests = []
            for name, dataset in [('train', trainset), ('test', testset)]:
                if opt.dataset == 'fashionIQ':
                    t = fiq_test(opt, model, dataset)
                else:
                    t = test(opt, model, dataset)
                tests += [(name + ' ' + metric_name, metric_value)
                          for metric_name, metric_value in t]
            for metric_name, metric_value in tests:
                logger.add_scalar(metric_name, metric_value, it)
                print('    ', metric_name, round(metric_value, 4))

        # save checkpoint
        torch.save({
            'it': it,
            'opt': opt,
            'model_state_dict': model.state_dict(),
        },
            logger.file_writer.get_logdir() + '/latest_checkpoint.pth')

        # run training for 1 epoch
        model.train()
        trainloader = trainset.get_loader(
            batch_size=opt.batch_size,
            shuffle=True,
            drop_last=True,
            num_workers=opt.loader_num_workers)

        def training_1_iter(data):
            assert type(data) is list
            img1 = np.stack([d['source_img_data'] for d in data])
            img1 = torch.from_numpy(img1).float()
            img1 = torch.autograd.Variable(img1).cuda()

            img2 = np.stack([d['target_img_data'] for d in data])
            img2 = torch.from_numpy(img2).float()
            img2 = torch.autograd.Variable(img2).cuda()

            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    supp_text = [str(d['noun']) for d in data]
                    mods = [str(d['mod']['str']) for d in data]
                    # text_query here means complete_text_query
                    text_query = [adj + " " + noun for adj, noun in zip(mods, supp_text)]
                else:
                    text_query = [str(d['target_caption']) for d in data]
            else:
                text_query = [str(d['mod']['str']) for d in data]
            # compute loss
            if opt.loss not in ['soft_triplet', 'batch_based_classification']:
                print('Invalid loss function', opt.loss)
                sys.exit()

            losses = []
            if_soft_triplet = True if opt.loss == 'soft_triplet' else False
            loss_value, dct_with_representations = model.compute_loss(img1,
                                                                      text_query,
                                                                      img2,
                                                                      soft_triplet_loss=if_soft_triplet)

            loss_name = opt.loss
            losses += [(loss_name, loss_weights[0], loss_value.cuda())]

            if opt.model == 'composeAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]
                losses += [("rot_sym_loss", loss_weights[3], dct_with_representations["rot_sym_loss"].cuda())]
            elif opt.model == 'RealSpaceConcatAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]

            total_loss = sum([
                loss_weight * loss_value
                for loss_name, loss_weight, loss_value in losses
            ])
            assert not torch.isnan(total_loss)
            losses += [('total training loss', None, total_loss.item())]

            # track losses
            for loss_name, loss_weight, loss_value in losses:
                if loss_name not in losses_tracking:
                    losses_tracking[loss_name] = []
                losses_tracking[loss_name].append(float(loss_value))

            torch.autograd.set_detect_anomaly(True)

            # gradient descendt
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        for data in tqdm(trainloader, desc='Training for epoch ' + str(epoch)):
            it += 1
            training_1_iter(data)

            # decay learning rate
            if it >= opt.learning_rate_decay_frequency and it % opt.learning_rate_decay_frequency == 0:
                for g in optimizer.param_groups:
                    g['lr'] *= 0.1

    print('Finished training')


def main():
    opt = parse_opt()
    print('Arguments:')
    for k in opt.__dict__.keys():
        print('    ', k, ':', str(opt.__dict__[k]))

    current_time = datetime.now().strftime('%b%d_%H-%M-%S')
    loss_weights = [1.0, 0.1, 0.1, 0.01]
    comment = opt.comment if opt.comment is not None else ''
    logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + comment)
    # logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + opt.comment)

    logger = SummaryWriter(logdir)
    print('Log files saved to', logger.file_writer.get_logdir())
    for k in opt.__dict__.keys():
        logger.add_text(k, str(opt.__dict__[k]))

    trainset, testset = load_dataset(opt)
    model, optimizer = create_model_and_optimizer(opt, [t for t in trainset.get_all_texts()])
    if opt.test_only:
        print('Doing test only')
        checkpoint = torch.load(opt.model_checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'])
        it = checkpoint['it']
        model.eval()
        tests = []
        it = 0
        for name, dataset in [('train', trainset), ('test', testset)]:
            if opt.dataset == 'fashionIQ':
                t = fiq_test(opt, model, dataset)
            else:
                t = test(opt, model, dataset)
            tests += [(name + ' ' + metric_name, metric_value) for metric_name, metric_value in t]
        for metric_name, metric_value in tests:
            logger.add_scalar(metric_name, metric_value, it)
            print('    ', metric_name, round(metric_value, 4))

        return 0
    train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
    logger.close()


if __name__ == '__main__':
    main()
# Out:
# Arguments:
#      f : /root/.local/share/jupyter/runtime/kernel-011ef976-1637-4fd1-9b07-537fe0b6ebfe.json
#      comment : mitstates_composeAE
#      dataset : mitstates
#      dataset_path : /content/data/mitstates
#      model : composeAE
#      image_embed_dim : 512
#      use_bert : True
#      use_complete_text_query : True
#      learning_rate : 0.001
#      learning_rate_decay_frequency : 50000
#      batch_size : 32
#      weight_decay : 5e-05
#      category_to_train : all
#      num_iters : 6750
#      loss : batch_based_classification
#      loader_num_workers : 4
#      log_dir : /content/logs/mitstates
#      test_only : False
#      model_checkpoint :
# Log files saved to /content/logs/mitstates/Dec13_19-47-11_92976d119f34mitstates_composeAE
# mitstates
# Reading dataset  mitstates
# 82732 test queries
# trainset size: 43207
# testset size: 10546
# Creating model and optimizer for composeAE
# Begin training
# 0 82732
# It 0 epoch 0 Elapsed time 0.0001 mitstates_composeAE
# Exception ignored in: <function StorageWeakRef.__del__ at 0x7a7ae0291bd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/multiprocessing/reductions.py", line 50, in __del__
#     self._free_weak_ref(self.cdata)
# AttributeError: 'StorageWeakRef' object has no attribute '_free_weak_ref'
# Training for epoch 0: 100%|██████████| 1350/1350 [06:55<00:00,  3.25it/s]
# It 1350 epoch 1 Elapsed time 416.8426 mitstates_composeAE
#     Loss batch_based_classification 2.408
#     Loss L2_loss 0.3504
#     Loss L2_loss_text 0.2688
#     Loss rot_sym_loss 3.4408
#     Loss total training loss 2.5043
# 100%|██████████| 82732/82732 [06:49<00:00, 201.84it/s]
# 100%|██████████| 10546/10546 [00:35<00:00, 299.76it/s]
#      train recall_top1_correct_composition 0.0478
#      train recall_top1_correct_adj 0.1161
#      train recall_top1_correct_noun 0.2515
#      train recall_top5_correct_composition 0.16
#      train recall_top5_correct_adj 0.3452
#      train recall_top5_correct_noun 0.5322
#      train recall_top10_correct_composition 0.2607
#      train recall_top10_correct_adj 0.5079
#      train recall_top10_correct_noun 0.6735
#      train recall_top50_correct_composition 0.5886
#      train recall_top50_correct_adj 0.8532
#      train recall_top50_correct_noun 0.9223
#      train recall_top100_correct_composition 0.7299
#      train recall_top100_correct_adj 0.9295
#      train recall_top100_correct_noun 0.9689
#      test recall_top1_correct_composition 0.0559
#      test recall_top1_correct_adj 0.1105
#      test recall_top1_correct_noun 0.3699
#      test recall_top5_correct_composition 0.1949
#      test recall_top5_correct_adj 0.3346
#      test recall_top5_correct_noun 0.7132
#      test recall_top10_correct_composition 0.2998
#      test recall_top10_correct_adj 0.4787
#      test recall_top10_correct_noun 0.821
#      test recall_top50_correct_composition 0.6254
#      test recall_top50_correct_adj 0.8228
#      test recall_top50_correct_noun 0.9616
#      test recall_top100_correct_composition 0.7548
#      test recall_top100_correct_adj 0.9096
#      test recall_top100_correct_noun 0.9858
# Training for epoch 1: 100%|██████████| 1350/1350 [06:57<00:00,  3.23it/s]
# It 2700 epoch 2 Elapsed time 986.9249 mitstates_composeAE
#     Loss batch_based_classification 1.947
#     Loss L2_loss 0.3475
#     Loss L2_loss_text 0.2218
#     Loss rot_sym_loss 3.7654
#     Loss total training loss 2.0416
# Training for epoch 2: 100%|██████████| 1350/1350 [06:55<00:00,  3.25it/s]
# It 4050 epoch 3 Elapsed time 417.2453 mitstates_composeAE
#     Loss batch_based_classification 1.7592
#     Loss L2_loss 0.352
#     Loss L2_loss_text 0.1798
#     Loss rot_sym_loss 3.8995
#     Loss total training loss 1.8514
# Training for epoch 3: 100%|██████████| 1350/1350 [06:53<00:00,  3.26it/s]
# It 5400 epoch 4 Elapsed time 415.4085 mitstates_composeAE
#     Loss batch_based_classification 1.625
#     Loss L2_loss 0.3497
#     Loss L2_loss_text 0.1422
#     Loss rot_sym_loss 3.9102
#     Loss total training loss 1.7133
# 100%|██████████| 82732/82732 [06:44<00:00, 204.78it/s]
# 100%|██████████| 10546/10546 [00:34<00:00, 301.79it/s]
#      train recall_top1_correct_composition 0.1467
#      train recall_top1_correct_adj 0.2767
#      train recall_top1_correct_noun 0.4138
#      train recall_top5_correct_composition 0.3812
#      train recall_top5_correct_adj 0.5797
#      train recall_top5_correct_noun 0.7295
#      train recall_top10_correct_composition 0.5254
#      train recall_top10_correct_adj 0.7393
#      train recall_top10_correct_noun 0.8522
#      train recall_top50_correct_composition 0.8454
#      train recall_top50_correct_adj 0.9559
#      train recall_top50_correct_noun 0.9779
#      train recall_top100_correct_composition 0.9264
#      train recall_top100_correct_adj 0.986
#      train recall_top100_correct_noun 0.9917
#      test recall_top1_correct_composition 0.0923
#      test recall_top1_correct_adj 0.1805
#      test recall_top1_correct_noun 0.4247
#      test recall_top5_correct_composition 0.2971
#      test recall_top5_correct_adj 0.465
#      test recall_top5_correct_noun 0.7207
#      test recall_top10_correct_composition 0.4177
#      test recall_top10_correct_adj 0.607
#      test recall_top10_correct_noun 0.8205
#      test recall_top50_correct_composition 0.7229
#      test recall_top50_correct_adj 0.8849
#      test recall_top50_correct_noun 0.962
#      test recall_top100_correct_composition 0.835
#      test recall_top100_correct_adj 0.9474
#      test recall_top100_correct_noun 0.9894
# Training for epoch 4: 100%|██████████| 1350/1350 [06:53<00:00,  3.26it/s]
# Finished training

# %%
"""Main method to train the model."""

# !/usr/bin/python

import argparse
import sys
import gc
import time
import numpy as np
from tensorboardX import SummaryWriter
from torch.autograd import Variable
import torch
import torch.utils.data
import torchvision
from tqdm import tqdm as tqdm
from copy import deepcopy
import socket
import os
from datetime import datetime

torch.set_num_threads(3)


def parse_opt():
    """Parses the input arguments."""
    parser = argparse.ArgumentParser()
    parser.add_argument('-f', type=str, default='')
    parser.add_argument('--comment', type=str, default= 'mitstates_composeAE')
    parser.add_argument('--dataset', type=str, default = 'mitstates')
    parser.add_argument('--dataset_path', type=str, default = '/content/data/mitstates')
    parser.add_argument('--model', type=str, default='composeAE')
    parser.add_argument('--image_embed_dim', type=int, default=512)
    parser.add_argument('--use_bert', type=bool, default=True)
    parser.add_argument('--use_complete_text_query', type=bool, default=True)
    parser.add_argument('--learning_rate', type=float, default=1e-4)
    parser.add_argument('--learning_rate_decay_frequency', type=int, default=50000 )
    parser.add_argument('--batch_size', type=int, default=32)
    parser.add_argument('--weight_decay', type=float, default=5e-5)
    parser.add_argument('--category_to_train', type=str, default='all')
    parser.add_argument('--num_iters', type=int, default=6750)
    parser.add_argument('--loss', type=str, default='batch_based_classification')
    parser.add_argument('--loader_num_workers', type=int, default=4)
    parser.add_argument('--log_dir', type=str, default='/content/logs/mitstates')
    parser.add_argument('--test_only', type=bool, default=False)
    parser.add_argument('--model_checkpoint', type=str, default='/content/logs/mitstates/Dec13_13-23-01_92976d119f34mitstates_composeAE/latest_checkpoint.pth')

    args = parser.parse_args()
    return args


def load_dataset(opt):
    """Loads the input datasets."""
    print(opt.dataset)
    print('Reading dataset ', opt.dataset)
    if opt.dataset == 'fashion200k':
        trainset = Fashion200k(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = Fashion200k(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'mitstates':
        trainset = MITStates(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = MITStates(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'fashionIQ':
        trainset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='val',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    else:
        print('Invalid dataset', opt.dataset)
        sys.exit()

    print('trainset size:', len(trainset))
    print('testset size:', len(testset))
    return trainset, testset


def create_model_and_optimizer(opt, texts):
    """Builds the model and related optimizer."""
    print("Creating model and optimizer for", opt.model)
    text_embed_dim = 512 if not opt.use_bert else 768

    if opt.model == 'tirg':
        model = TIRG(texts,
                                                 image_embed_dim=opt.image_embed_dim,
                                                 text_embed_dim=text_embed_dim,
                                                 use_bert=opt.use_bert,
                                                 name= opt.model)
    elif opt.model == 'composeAE':
        model = ComposeAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    elif opt.model == 'RealSpaceConcatAE':
        model = RealSpaceConcatAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    model = model.cuda()

    # create optimizer
    params = [{
        'params': [p for p in model.img_model.fc.parameters()],
        'lr': opt.learning_rate
    }, {
        'params': [p for p in model.img_model.parameters()],
        'lr': 0.1 * opt.learning_rate
    }, {'params': [p for p in model.parameters()]}]

    for _, p1 in enumerate(params):  # remove duplicated params
        for _, p2 in enumerate(params):
            if p1 is not p2:
                for p11 in p1['params']:
                    for j, p22 in enumerate(p2['params']):
                        if p11 is p22:
                            p2['params'][j] = torch.tensor(0.0, requires_grad=True)

    optimizer = torch.optim.SGD(params,
                                lr=opt.learning_rate,
                                momentum=0.9,
                                weight_decay=opt.weight_decay)

    return model, optimizer


def train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer):
    """Function for train loop"""
    print('Begin training')
    print(len(trainset.test_queries), len(testset.test_queries))
    torch.backends.cudnn.benchmark = True
    losses_tracking = {}
    it = 0
    epoch = -1
    tic = time.time()
    l2_loss = torch.nn.MSELoss().cuda()

    while it < opt.num_iters:
        epoch += 1

        # show/log stats
        print('It', it, 'epoch', epoch, 'Elapsed time', round(time.time() - tic,
                                                              4), opt.comment)
        tic = time.time()
        for loss_name in losses_tracking:
            avg_loss = np.mean(losses_tracking[loss_name][-len(trainloader):])
            print('    Loss', loss_name, round(avg_loss, 4))
            logger.add_scalar(loss_name, avg_loss, it)
        logger.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], it)

        if epoch % 1 == 0:
            gc.collect()

        # test
        if epoch % 3 == 1:
            tests = []
            for name, dataset in [('train', trainset), ('test', testset)]:
                if opt.dataset == 'fashionIQ':
                    t = fiq_test(opt, model, dataset)
                else:
                    t = test(opt, model, dataset)
                tests += [(name + ' ' + metric_name, metric_value)
                          for metric_name, metric_value in t]
            for metric_name, metric_value in tests:
                logger.add_scalar(metric_name, metric_value, it)
                print('    ', metric_name, round(metric_value, 4))

        # save checkpoint
        torch.save({
            'it': it,
            'opt': opt,
            'model_state_dict': model.state_dict(),
        },
            logger.file_writer.get_logdir() + '/latest_checkpoint.pth')

        # run training for 1 epoch
        model.train()
        trainloader = trainset.get_loader(
            batch_size=opt.batch_size,
            shuffle=True,
            drop_last=True,
            num_workers=opt.loader_num_workers)

        def training_1_iter(data):
            assert type(data) is list
            img1 = np.stack([d['source_img_data'] for d in data])
            img1 = torch.from_numpy(img1).float()
            img1 = torch.autograd.Variable(img1).cuda()

            img2 = np.stack([d['target_img_data'] for d in data])
            img2 = torch.from_numpy(img2).float()
            img2 = torch.autograd.Variable(img2).cuda()

            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    supp_text = [str(d['noun']) for d in data]
                    mods = [str(d['mod']['str']) for d in data]
                    # text_query here means complete_text_query
                    text_query = [adj + " " + noun for adj, noun in zip(mods, supp_text)]
                else:
                    text_query = [str(d['target_caption']) for d in data]
            else:
                text_query = [str(d['mod']['str']) for d in data]
            # compute loss
            if opt.loss not in ['soft_triplet', 'batch_based_classification']:
                print('Invalid loss function', opt.loss)
                sys.exit()

            losses = []
            if_soft_triplet = True if opt.loss == 'soft_triplet' else False
            loss_value, dct_with_representations = model.compute_loss(img1,
                                                                      text_query,
                                                                      img2,
                                                                      soft_triplet_loss=if_soft_triplet)

            loss_name = opt.loss
            losses += [(loss_name, loss_weights[0], loss_value.cuda())]

            if opt.model == 'composeAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]
                losses += [("rot_sym_loss", loss_weights[3], dct_with_representations["rot_sym_loss"].cuda())]
            elif opt.model == 'RealSpaceConcatAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]

            total_loss = sum([
                loss_weight * loss_value
                for loss_name, loss_weight, loss_value in losses
            ])
            # assert not torch.isnan(total_loss)
            losses += [('total training loss', None, total_loss.item())]

            # track losses
            for loss_name, loss_weight, loss_value in losses:
                if loss_name not in losses_tracking:
                    losses_tracking[loss_name] = []
                losses_tracking[loss_name].append(float(loss_value))

            torch.autograd.set_detect_anomaly(True)

            # gradient descendt
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        for data in tqdm(trainloader, desc='Training for epoch ' + str(epoch)):
            it += 1
            training_1_iter(data)

            # decay learning rate
            if it >= opt.learning_rate_decay_frequency and it % opt.learning_rate_decay_frequency == 0:
                for g in optimizer.param_groups:
                    g['lr'] *= 0.1

    print('Finished training')


def main():
    opt = parse_opt()
    print('Arguments:')
    for k in opt.__dict__.keys():
        print('    ', k, ':', str(opt.__dict__[k]))

    current_time = datetime.now().strftime('%b%d_%H-%M-%S')
    loss_weights = [1.0, 0.1, 0.1, 0.01]
    comment = opt.comment if opt.comment is not None else ''
    logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + comment)
    # logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + opt.comment)

    logger = SummaryWriter(logdir)
    print('Log files saved to', logger.file_writer.get_logdir())
    for k in opt.__dict__.keys():
        logger.add_text(k, str(opt.__dict__[k]))

    trainset, testset = load_dataset(opt)
    model, optimizer = create_model_and_optimizer(opt, [t for t in trainset.get_all_texts()])
    if opt.test_only:
        print('Doing test only')
        checkpoint = torch.load(opt.model_checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'])
        it = checkpoint['it']
        model.eval()
        tests = []
        it = 0
        for name, dataset in [('train', trainset), ('test', testset)]:
            if opt.dataset == 'fashionIQ':
                t = fiq_test(opt, model, dataset)
            else:
                t = test(opt, model, dataset)
            tests += [(name + ' ' + metric_name, metric_value) for metric_name, metric_value in t]
        for metric_name, metric_value in tests:
            logger.add_scalar(metric_name, metric_value, it)
            print('    ', metric_name, round(metric_value, 4))

        return 0
    train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
    logger.close()


if __name__ == '__main__':
    main()
# Out:
# Arguments:
#      f : /root/.local/share/jupyter/runtime/kernel-011ef976-1637-4fd1-9b07-537fe0b6ebfe.json
#      comment : mitstates_composeAE
#      dataset : mitstates
#      dataset_path : /content/data/mitstates
#      model : composeAE
#      image_embed_dim : 512
#      use_bert : True
#      use_complete_text_query : True
#      learning_rate : 0.0001
#      learning_rate_decay_frequency : 50000
#      batch_size : 32
#      weight_decay : 5e-05
#      category_to_train : all
#      num_iters : 5400
#      loss : batch_based_classification
#      loader_num_workers : 4
#      log_dir : /content/logs/mitstates
#      test_only : False
#      model_checkpoint : /content/logs/mitstates/Dec13_13-23-01_92976d119f34mitstates_composeAE/latest_checkpoint.pth
# Log files saved to /content/logs/mitstates/Dec13_22-20-36_92976d119f34mitstates_composeAE
# mitstates
# Reading dataset  mitstates
# 82732 test queries
# trainset size: 43207
# testset size: 10546
# Creating model and optimizer for composeAE
# Begin training
# 0 82732
# It 0 epoch 0 Elapsed time 0.0001 mitstates_composeAE
# Training for epoch 0: 100%|██████████| 1350/1350 [06:58<00:00,  3.22it/s]
# It 1350 epoch 1 Elapsed time 419.8334 mitstates_composeAE
#     Loss batch_based_classification 3.1371
#     Loss L2_loss 0.4461
#     Loss L2_loss_text 0.2878
#     Loss rot_sym_loss 3.3582
#     Loss total training loss 3.2441
# 100%|██████████| 82732/82732 [06:48<00:00, 202.72it/s]
# 100%|██████████| 10546/10546 [00:36<00:00, 291.83it/s]
#      train recall_top1_correct_composition 0.0108
#      train recall_top1_correct_adj 0.046
#      train recall_top1_correct_noun 0.0781
#      train recall_top5_correct_composition 0.044
#      train recall_top5_correct_adj 0.1695
#      train recall_top5_correct_noun 0.2415
#      train recall_top10_correct_composition 0.0727
#      train recall_top10_correct_adj 0.2701
#      train recall_top10_correct_noun 0.3669
#      train recall_top50_correct_composition 0.2452
#      train recall_top50_correct_adj 0.616
#      train recall_top50_correct_noun 0.7104
#      train recall_top100_correct_composition 0.368
#      train recall_top100_correct_adj 0.7603
#      train recall_top100_correct_noun 0.836
#      test recall_top1_correct_composition 0.0183
#      test recall_top1_correct_adj 0.042
#      test recall_top1_correct_noun 0.1795
#      test recall_top5_correct_composition 0.0773
#      test recall_top5_correct_adj 0.1667
#      test recall_top5_correct_noun 0.4711
#      test recall_top10_correct_composition 0.1361
#      test recall_top10_correct_adj 0.2789
#      test recall_top10_correct_noun 0.6313
#      test recall_top50_correct_composition 0.3846
#      test recall_top50_correct_adj 0.6313
#      test recall_top50_correct_noun 0.8825
#      test recall_top100_correct_composition 0.5316
#      test recall_top100_correct_adj 0.7678
#      test recall_top100_correct_noun 0.9376
# Training for epoch 1: 100%|██████████| 1350/1350 [06:58<00:00,  3.23it/s]
# It 2700 epoch 2 Elapsed time 986.2952 mitstates_composeAE
#     Loss batch_based_classification 2.6823
#     Loss L2_loss 0.3497
#     Loss L2_loss_text 0.2814
#     Loss rot_sym_loss 3.1831
#     Loss total training loss 2.7773
# Training for epoch 2: 100%|██████████| 1350/1350 [06:57<00:00,  3.23it/s]
# It 4050 epoch 3 Elapsed time 419.6044 mitstates_composeAE
#     Loss batch_based_classification 2.499
#     Loss L2_loss 0.3159
#     Loss L2_loss_text 0.2758
#     Loss rot_sym_loss 3.2341
#     Loss total training loss 2.5906
# Training for epoch 3: 100%|██████████| 1350/1350 [06:56<00:00,  3.24it/s]
# Finished training

# %%
"""Main method to train the model."""

# !/usr/bin/python

import argparse
import sys
import gc
import time
import numpy as np
from tensorboardX import SummaryWriter
from torch.autograd import Variable
import torch
import torch.utils.data
import torchvision
from tqdm import tqdm as tqdm
from copy import deepcopy
import socket
import os
from datetime import datetime

torch.set_num_threads(3)


def parse_opt():
    """Parses the input arguments."""
    parser = argparse.ArgumentParser()
    parser.add_argument('-f', type=str, default='')
    parser.add_argument('--comment', type=str, default= 'mitstates_composeAE')
    parser.add_argument('--dataset', type=str, default = 'mitstates')
    parser.add_argument('--dataset_path', type=str, default = '/content/data/mitstates')
    parser.add_argument('--model', type=str, default='composeAE')
    parser.add_argument('--image_embed_dim', type=int, default=512)
    parser.add_argument('--use_bert', type=bool, default=True)
    parser.add_argument('--use_complete_text_query', type=bool, default=True)
    parser.add_argument('--learning_rate', type=float, default=1e-2)
    parser.add_argument('--learning_rate_decay_frequency', type=int, default=50000 )
    parser.add_argument('--batch_size', type=int, default=64)
    parser.add_argument('--weight_decay', type=float, default=5e-5)
    parser.add_argument('--category_to_train', type=str, default='all')
    parser.add_argument('--num_iters', type=int, default=6750)
    parser.add_argument('--loss', type=str, default='batch_based_classification')
    parser.add_argument('--loader_num_workers', type=int, default=4)
    parser.add_argument('--log_dir', type=str, default='/content/logs/mitstates')
    parser.add_argument('--test_only', type=bool, default=False)
    parser.add_argument('--model_checkpoint', type=str, default='/content/logs/mitstates/Dec13_13-23-01_92976d119f34mitstates_composeAE/latest_checkpoint.pth')

    args = parser.parse_args()
    return args


def load_dataset(opt):
    """Loads the input datasets."""
    print(opt.dataset)
    print('Reading dataset ', opt.dataset)
    if opt.dataset == 'fashion200k':
        trainset = Fashion200k(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = Fashion200k(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'mitstates':
        trainset = MITStates(
            path=opt.dataset_path,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = MITStates(
            path=opt.dataset_path,
            split='test',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    elif opt.dataset == 'fashionIQ':
        trainset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='train',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
        testset = FashionIQ(
            path=opt.dataset_path,
            cat_type=opt.category_to_train,
            split='val',
            transform=torchvision.transforms.Compose([
                torchvision.transforms.Resize(224),
                torchvision.transforms.CenterCrop(224),
                torchvision.transforms.ToTensor(),
                torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                                 [0.229, 0.224, 0.225])
            ]))
    else:
        print('Invalid dataset', opt.dataset)
        sys.exit()

    print('trainset size:', len(trainset))
    print('testset size:', len(testset))
    return trainset, testset


def create_model_and_optimizer(opt, texts):
    """Builds the model and related optimizer."""
    print("Creating model and optimizer for", opt.model)
    text_embed_dim = 512 if not opt.use_bert else 768

    if opt.model == 'tirg':
        model = TIRG(texts,
                                                 image_embed_dim=opt.image_embed_dim,
                                                 text_embed_dim=text_embed_dim,
                                                 use_bert=opt.use_bert,
                                                 name= opt.model)
    elif opt.model == 'composeAE':
        model = ComposeAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    elif opt.model == 'RealSpaceConcatAE':
        model = RealSpaceConcatAE(texts,
                                                     image_embed_dim=opt.image_embed_dim,
                                                     text_embed_dim=text_embed_dim,
                                                     use_bert=opt.use_bert,
                                                     name = opt.model)
    model = model.cuda()

    # create optimizer
    params = [{
        'params': [p for p in model.img_model.fc.parameters()],
        'lr': opt.learning_rate
    }, {
        'params': [p for p in model.img_model.parameters()],
        'lr': 0.1 * opt.learning_rate
    }, {'params': [p for p in model.parameters()]}]

    for _, p1 in enumerate(params):  # remove duplicated params
        for _, p2 in enumerate(params):
            if p1 is not p2:
                for p11 in p1['params']:
                    for j, p22 in enumerate(p2['params']):
                        if p11 is p22:
                            p2['params'][j] = torch.tensor(0.0, requires_grad=True)

    optimizer = torch.optim.SGD(params,
                                lr=opt.learning_rate,
                                momentum=0.9,
                                weight_decay=opt.weight_decay)

    return model, optimizer


def train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer):
    """Function for train loop"""
    print('Begin training')
    print(len(trainset.test_queries), len(testset.test_queries))
    torch.backends.cudnn.benchmark = True
    losses_tracking = {}
    it = 0
    epoch = -1
    tic = time.time()
    l2_loss = torch.nn.MSELoss().cuda()

    while it < opt.num_iters:
        epoch += 1

        # show/log stats
        print('It', it, 'epoch', epoch, 'Elapsed time', round(time.time() - tic,
                                                              4), opt.comment)
        tic = time.time()
        for loss_name in losses_tracking:
            avg_loss = np.mean(losses_tracking[loss_name][-len(trainloader):])
            print('    Loss', loss_name, round(avg_loss, 4))
            logger.add_scalar(loss_name, avg_loss, it)
        logger.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], it)

        if epoch % 1 == 0:
            gc.collect()

        # test
        if epoch % 3 == 1:
            tests = []
            for name, dataset in [('train', trainset), ('test', testset)]:
                if opt.dataset == 'fashionIQ':
                    t = fiq_test(opt, model, dataset)
                else:
                    t = test(opt, model, dataset)
                tests += [(name + ' ' + metric_name, metric_value)
                          for metric_name, metric_value in t]
            for metric_name, metric_value in tests:
                logger.add_scalar(metric_name, metric_value, it)
                print('    ', metric_name, round(metric_value, 4))

        # save checkpoint
        torch.save({
            'it': it,
            'opt': opt,
            'model_state_dict': model.state_dict(),
        },
            logger.file_writer.get_logdir() + '/latest_checkpoint.pth')

        # run training for 1 epoch
        model.train()
        trainloader = trainset.get_loader(
            batch_size=opt.batch_size,
            shuffle=True,
            drop_last=True,
            num_workers=opt.loader_num_workers)

        def training_1_iter(data):
            assert type(data) is list
            img1 = np.stack([d['source_img_data'] for d in data])
            img1 = torch.from_numpy(img1).float()
            img1 = torch.autograd.Variable(img1).cuda()

            img2 = np.stack([d['target_img_data'] for d in data])
            img2 = torch.from_numpy(img2).float()
            img2 = torch.autograd.Variable(img2).cuda()

            if opt.use_complete_text_query:
                if opt.dataset == 'mitstates':
                    supp_text = [str(d['noun']) for d in data]
                    mods = [str(d['mod']['str']) for d in data]
                    # text_query here means complete_text_query
                    text_query = [adj + " " + noun for adj, noun in zip(mods, supp_text)]
                else:
                    text_query = [str(d['target_caption']) for d in data]
            else:
                text_query = [str(d['mod']['str']) for d in data]
            # compute loss
            if opt.loss not in ['soft_triplet', 'batch_based_classification']:
                print('Invalid loss function', opt.loss)
                sys.exit()

            losses = []
            if_soft_triplet = True if opt.loss == 'soft_triplet' else False
            loss_value, dct_with_representations = model.compute_loss(img1,
                                                                      text_query,
                                                                      img2,
                                                                      soft_triplet_loss=if_soft_triplet)

            loss_name = opt.loss
            losses += [(loss_name, loss_weights[0], loss_value.cuda())]

            if opt.model == 'composeAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]
                losses += [("rot_sym_loss", loss_weights[3], dct_with_representations["rot_sym_loss"].cuda())]
            elif opt.model == 'RealSpaceConcatAE':
                dec_img_loss = l2_loss(dct_with_representations["repr_to_compare_with_source"],
                                   dct_with_representations["img_features"])
                dec_text_loss = l2_loss(dct_with_representations["repr_to_compare_with_mods"],
                                        dct_with_representations["text_features"])

                losses += [("L2_loss", loss_weights[1], dec_img_loss.cuda())]
                losses += [("L2_loss_text", loss_weights[2], dec_text_loss.cuda())]

            total_loss = sum([
                loss_weight * loss_value
                for loss_name, loss_weight, loss_value in losses
            ])
            # assert not torch.isnan(total_loss)
            losses += [('total training loss', None, total_loss.item())]

            # track losses
            for loss_name, loss_weight, loss_value in losses:
                if loss_name not in losses_tracking:
                    losses_tracking[loss_name] = []
                losses_tracking[loss_name].append(float(loss_value))

            torch.autograd.set_detect_anomaly(True)

            # gradient descendt
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

        for data in tqdm(trainloader, desc='Training for epoch ' + str(epoch)):
            it += 1
            training_1_iter(data)

            # decay learning rate
            if it >= opt.learning_rate_decay_frequency and it % opt.learning_rate_decay_frequency == 0:
                for g in optimizer.param_groups:
                    g['lr'] *= 0.1

    print('Finished training')


def main():
    opt = parse_opt()
    print('Arguments:')
    for k in opt.__dict__.keys():
        print('    ', k, ':', str(opt.__dict__[k]))

    current_time = datetime.now().strftime('%b%d_%H-%M-%S')
    loss_weights = [1.0, 0.1, 0.1, 0.01]
    comment = opt.comment if opt.comment is not None else ''
    logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + comment)
    # logdir = os.path.join(opt.log_dir, current_time + '_' + socket.gethostname() + opt.comment)

    logger = SummaryWriter(logdir)
    print('Log files saved to', logger.file_writer.get_logdir())
    for k in opt.__dict__.keys():
        logger.add_text(k, str(opt.__dict__[k]))

    trainset, testset = load_dataset(opt)
    model, optimizer = create_model_and_optimizer(opt, [t for t in trainset.get_all_texts()])
    if opt.test_only:
        print('Doing test only')
        checkpoint = torch.load(opt.model_checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'])
        it = checkpoint['it']
        model.eval()
        tests = []
        it = 0
        for name, dataset in [('train', trainset), ('test', testset)]:
            if opt.dataset == 'fashionIQ':
                t = fiq_test(opt, model, dataset)
            else:
                t = test(opt, model, dataset)
            tests += [(name + ' ' + metric_name, metric_value) for metric_name, metric_value in t]
        for metric_name, metric_value in tests:
            logger.add_scalar(metric_name, metric_value, it)
            print('    ', metric_name, round(metric_value, 4))

        return 0
    train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
    logger.close()


if __name__ == '__main__':
    main()
# Out:
# Arguments:
#      f : /root/.local/share/jupyter/runtime/kernel-011ef976-1637-4fd1-9b07-537fe0b6ebfe.json
#      comment : mitstates_composeAE
#      dataset : mitstates
#      dataset_path : /content/data/mitstates
#      model : composeAE
#      image_embed_dim : 512
#      use_bert : True
#      use_complete_text_query : True
#      learning_rate : 0.01
#      learning_rate_decay_frequency : 50000
#      batch_size : 64
#      weight_decay : 5e-05
#      category_to_train : all
#      num_iters : 6750
#      loss : batch_based_classification
#      loader_num_workers : 4
#      log_dir : /content/logs/mitstates
#      test_only : False
#      model_checkpoint : /content/logs/mitstates/Dec13_13-23-01_92976d119f34mitstates_composeAE/latest_checkpoint.pth
# Log files saved to /content/logs/mitstates/Dec13_23-10-18_92976d119f34mitstates_composeAE
# mitstates
# Reading dataset  mitstates
# 82732 test queries
# trainset size: 43207
# testset size: 10546
# Creating model and optimizer for composeAE
# Begin training
# 0 82732
# It 0 epoch 0 Elapsed time 0.0001 mitstates_composeAE
# Training for epoch 0:   0%|          | 0/675 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-0a82f8c267a9> in <cell line: 363>()
#     362
#     363 if __name__ == '__main__':
# --> 364     main()
#
# <ipython-input-36-0a82f8c267a9> in main()
#     357
#     358         return 0
# --> 359     train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
#     360     logger.close()
#     361
#
# <ipython-input-36-0a82f8c267a9> in train_loop(opt, loss_weights, logger, trainset, testset, model, optimizer)
#     309         for data in tqdm(trainloader, desc='Training for epoch ' + str(epoch)):
#     310             it += 1
# --> 311             training_1_iter(data)
#     312
#     313             # decay learning rate
#
# <ipython-input-36-0a82f8c267a9> in training_1_iter(data)
#     261             losses = []
#     262             if_soft_triplet = True if opt.loss == 'soft_triplet' else False
# --> 263             loss_value, dct_with_representations = model.compute_loss(img1,
#     264                                                                       text_query,
#     265                                                                       img2,
#
# <ipython-input-22-678105f6cb15> in compute_loss(self, imgs_query, text_query, imgs_target, soft_triplet_loss)
#      45                      imgs_target,
#      46                      soft_triplet_loss=True):
# ---> 47         dct_with_representations = self.compose_img_text(imgs_query, text_query)
#      48         composed_source_image = self.normalization_layer(dct_with_representations["repres"])
#      49         target_img_features_non_norm = self.extract_img_feature(imgs_target)
#
# <ipython-input-22-678105f6cb15> in compose_img_text(self, imgs, text_query)
#     329         text_features = self.extract_text_feature(text_query, self.use_bert)
#     330
# --> 331         return self.compose_img_text_features(img_features, text_features)
#     332
#     333     def compose_img_text_features(self, img_features, text_features, CONJUGATE = Variable(torch.cuda.FloatTensor(32, 1).fill_(1.0), requires_grad=False)):
#
# <ipython-input-22-678105f6cb15> in compose_img_text_features(self, img_features, text_features, CONJUGATE)
#     332
#     333     def compose_img_text_features(self, img_features, text_features, CONJUGATE = Variable(torch.cuda.FloatTensor(32, 1).fill_(1.0), requires_grad=False)):
# --> 334         theta_linear = self.encoderLinear((img_features, text_features, CONJUGATE))
#     335         theta_conv = self.encoderWithConv((img_features, text_features, CONJUGATE))
#     336         theta = theta_linear * self.a[1] + theta_conv * self.a[0]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-22-678105f6cb15> in forward(self, x)
#     228         delta = x2  # text as rotation
#     229         re_delta = torch.cos(delta)
# --> 230         im_delta = CONJUGATE * torch.sin(delta)
#     231
#     232         re_score = x1 * re_delta
#
# RuntimeError: The size of tensor a (32) must match the size of tensor b (64) at non-singleton dimension 0
